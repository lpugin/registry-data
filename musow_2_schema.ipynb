# %% [markdown]
# # musoW to schema.org
#
# ## Imports

# %%
from datetime import datetime
import re

# google auth
from google.colab import auth
import gspread
from oauth2client.client import GoogleCredentials

# data
import pandas as pd
import numpy as np
import hashlib

# !pip install rdflib
from rdflib import Graph, Literal, RDF, URIRef, ConjunctiveGraph, Namespace
from rdflib.namespace import FOAF , XSD, OWL, DC , RDF , RDFS

# download 
from google.colab import files
# Out:
# Collecting rdflib
#   Downloading rdflib-6.0.2-py3-none-any.whl (407 kB)
#      |████████████████████████████████| 407 kB 5.1 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from rdflib) (57.4.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from rdflib) (2.4.7)
# Collecting isodate
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 2.5 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from isodate->rdflib) (1.15.0)
# Installing collected packages: isodate, rdflib
# Successfully installed isodate-0.6.0 rdflib-6.0.2

# %% [markdown]
# ## Parse google spreadsheet

# %%
# old musoW backup (include errors)
# https://raw.githubusercontent.com/polifonia-project/registry-data/master/dataset.nt

# musow new schema (summary tab new properties)
# https://docs.google.com/spreadsheets/d/1SXwn1PbqkW4DhgzKel2ofUgr681yOpb_wIRy4rc5zpM/edit?usp=sharing

# authenticate
auth.authenticate_user()

# spreadsheet: Research topics
gc = gspread.authorize(GoogleCredentials.get_application_default())
spreadsheet = gc.open('Polifonia Registry (musoW Survey)')
topics = spreadsheet.get_worksheet(3) # tab resources

# Transform tables to dataframes
def make_header(df):
  new_header = df.iloc[0] 
  df = df[1:] 
  df.columns = new_header
  return df

# dataframe
rows = topics.get_all_values()
df = pd.DataFrame.from_records(rows)
df = make_header(df)
df.head()
# Out:
# 0 Person  ... Target audience
# 1     MD  ...     researchers
# 2     MD  ...     researchers
# 3     MD  ...     researchers
# 4     MD  ...     researchers
# 5     MD  ...     researchers
#
# [5 rows x 47 columns]

# %% [markdown]
# ## Utils

# %%
def ts():
  now = datetime.now()
  timestamp = datetime.timestamp(now)
  return str(timestamp).replace('.','-')

def urid(s):
  return str(hashlib.md5(s.encode()).hexdigest())

def camel_case_split(identifier):
    matches = re.finditer('.+?(?:(?<=[a-z])(?=[A-Z])|(?<=[A-Z])(?=[A-Z][a-z])|$)', identifier)
    return " ".join([m.group(0) for m in matches])

def column_to_json(field_id, field_disambiguate, field_value_type, field_prepend,
                   field_label, field_type, field_property, field_placeholder,
                   field_browse, field_searchWikidata, field_disabled,
                   field_class, field_cache, field_values=None):
  json_field = {}
  json_field["id"] = field_id
  json_field["disambiguate"] = field_disambiguate
  json_field["value"] = field_value_type
  json_field["prepend"] = field_prepend
  json_field["label"] = field_label
  json_field["type"] = field_type
  json_field["property"] = field_property
  json_field["placeholder"] = field_placeholder
  json_field["browse"] = field_browse
  json_field["searchWikidata"] = field_searchWikidata
  json_field["disabled"] = field_disabled
  json_field["class"] = field_class
  json_field["cache_autocomplete"] = field_cache 
  if field_values:
    json_field["values"] = field_values
  return json_field

# %% [markdown]
# ## Setup graphs

# %%
base = 'https://w3id.org/musow/'
vocab = 'https://w3id.org/musow/vocab/'
schema = "https://schema.org/"

SCHEMA = Namespace(schema)
BASE = Namespace(base)
VOCAB = Namespace(vocab)
MO = Namespace("http://purl.org/ontology/mo/")
PROV = Namespace("http://www.w3.org/ns/prov#")

#dft = df[10:13] # CHANGE

g = ConjunctiveGraph()
g.bind("schema", SCHEMA)
g.bind("musow", BASE)
g.bind("prov", PROV)

# controlled vocabularies
vocab_graph = URIRef(BASE+'vocabularies/')

# %% [markdown]
# ## Controlled vocabularies

# %%
res_types = {
    "Dataset": vocab+'dataset',
    "Repository": vocab+'repository',
    "Service": vocab+'service',
    "Software": vocab+'software',
    "Schema": vocab+'schema',
    "Catalogue": vocab+'catalogue',
    "Digital Library": vocab+'digital-library',
    "Ontology": vocab+'ontology',
    "Digital edition": vocab+'digital-edition',
    "Format": vocab+'format',
    "Project": vocab+'project'
}

res_educational = {
    "Learning": vocab+'learning',
    "Research": vocab+"research"
}

res_audiences = list({a.strip().lower() for a in ";".join(df["Target audience"].unique().tolist()).split(';') if len(a) > 1})
res_audiences = {k:vocab+k.strip().lower().replace(" ","-") for k in res_audiences if k}

res_scope = {
    "Temporal":vocab+"temporal",
    "Geographical":vocab+"geographical",
    "Genre":vocab+"genre",
    "Artist": vocab+"artist"
}

res_mo_types = ["AnalogSignal","MusicalWork","Signal","Record","Recording","Track","Libretto","Score","Performance","MusicArtist","Instrument","MusicalManifestation"]
res_mo_types = {camel_case_split(k):"http://purl.org/ontology/mo/"+k for k in res_mo_types if k}

res_subject_types = ["Tabs","Audio","Musical resource","Listening experience","Publisher"]
res_subject_types = {k:vocab+k.lower().replace(" ","-") for k in res_subject_types if k} 

res_app_features = {
    "Shares data in open data formats": vocab+'interoperable',
    "Provides user-friendly interfaces": vocab+'human-consumption',
    "Offers playable music records": vocab+'playable',
    "Serves machine-readable music data": vocab+'machine-readable',
    "Offers a Web API":vocab+'api',
    "Has a SPARQL endpoint": vocab+'sparql-endpoint',
    "Provides user-friendly search interfaces":vocab+'search-interface',
    "Provides interfaces for browsing contents": vocab+'browse-interface',
    "Offers data export or dump": vocab+'data-dump'
}


res_categories = {k:vocab+k.lower().replace(" ","-") for k in df["Category"].unique().tolist() if k}

res_data_features = {
    "Melody": vocab+'melody',
    "Harmony": vocab+'harmony',
    "Lyrics": vocab+'lyrics',
    "Rhythm": vocab+'rhythm',
    "Timbre": vocab+'timbre',
    "Contour/Shape": vocab+'contour-shape',
    "Music structure":vocab+'structure',
    "Descriptive metadata": vocab+'descriptive-metadata'
}

res_formats = list({a.strip().lower() for a in ",".join(df["Scope: Formats"].unique().tolist()).split(',') if len(a) > 1})
res_formats = {k:vocab+k.strip().lower().replace(" ","-") for k in res_formats if k}


res_licenses = {k:vocab+k.lower().replace(" ","-") for k in df["Access: license"].unique().tolist() if k}


res_collection_size = {k:vocab+k.lower().replace("<",'lt-').replace(">",'gt-').replace(" ","-") for k in df["Collection: Size"].unique().tolist() if k and k != 'N/A' and k != 'UNKNOWN'}


res_datasize = {k:vocab+k.lower().replace("~",'') for k in df["Data size"].unique().tolist() if k and k != 'N/A' and k != 'UNKNOWN'}


res_tasks = list({a.strip().lower() for a in ";".join(df["Situation/Task"].unique().tolist()).split(';') if len(a) > 1})
res_tasks = {k:vocab+k.strip().lower().replace(" ","-") for k in res_tasks if k}

# %% [markdown]
# ## Create graphs

# %%
# create ids for every resource (for interlinking)
ids = {}
for index, row in df.iterrows():
  ids[index] = ts()

# create a graph for each row
for index, row in df.iterrows():
  loc_id = ids[index]
  res = URIRef(base+loc_id)
  g_name = res+'/'
  res_id = urid(row["ID: Resource name"])
  #res = URIRef(BASE+res_id)
  
  # STR: title
  res_title = row["ID: Resource name"]
  g.add(( res , RDF.type , SCHEMA.CreativeWork , g_name ))
  g.add(( res , OWL.sameAs , URIRef("http://data.open.ac.uk/musow/"+res_id) , g_name ))
  g.add(( res , RDFS.label , Literal(res_title.strip()) , g_name ))
  g.add(( res , SCHEMA.name , Literal(res_title.strip()) , g_name ))

  # URI: homepage
  res_home = row["ID: URL"]
  if len(res_home):
    g.add(( res , SCHEMA.mainEntityOfPage , URIRef(res_home.strip()) , g_name ))

  # STR: description
  res_desc = row["Description"]
  if len(res_desc):
    g.add(( res , SCHEMA.description , Literal(res_desc) , g_name ))

  # URI: project or creator 
  res_project = row["Project"]
  if len(res_project):
    projects = [f.strip() for f in res_project.split(',')]
    for f in projects:
      # search for the index of the resource
      idx = df.index[df["ID: Resource name"] == f].tolist()
      res_project_uri = URIRef(BASE+ids[idx[0]]) if len(idx) == 1 else URIRef(BASE+urid(f))
      g.add(( res , SCHEMA.creator , res_project_uri , g_name ))
      g.add(( res_project_uri, RDFS.label , Literal(f.strip()) , g_name ))

  # VOCAB: additionalType
  res_type = row["Resource type"]
  res_type_uri = URIRef(VOCAB+res_type.lower().replace(" ","-"))
  g.add(( res , SCHEMA.additionalType , res_type_uri , g_name ))
  g.add(( res_type_uri, RDFS.label , Literal(res_type.strip()) , g_name ))
  g.add(( res_type_uri, RDFS.label , Literal(res_type.strip()) , vocab_graph ))

  # VOCAB: educationalUse
  res_purpose = ["Learning"] if row["Purpose: Learning"] == "Y" \
                              and row["Purpose: Research"] == "N" else \
                 ["Research"] if row["Purpose: Learning"] == "N" \
                              and row["Purpose: Research"] == "Y" else \
                 ["Research", "Learning"] if row["Purpose: Learning"] == "Y" \
                              and row["Purpose: Research"] == "Y" else  []
  
  if len(res_purpose) > 0:
    for r in res_purpose:
      res_purpose_uri = URIRef(VOCAB+r.lower().replace(" ","-"))
      g.add(( res , SCHEMA.educationalUse , res_purpose_uri , g_name ))
      g.add(( res_purpose_uri, RDFS.label , Literal(r.strip()) , g_name ))
      g.add(( res_purpose_uri, RDFS.label , Literal(r.strip()) , vocab_graph ))

  # VOCAB: audience
  res_audience = row["Target audience"].split(';')
  if len(res_audience) > 0:
    for r in res_audience:
      res_audience_uri = URIRef(VOCAB+r.strip().lower().replace(" ","-"))
      g.add(( res , SCHEMA.audience , res_audience_uri , g_name ))
      g.add(( res_audience_uri, RDFS.label , Literal(r.strip()) , g_name ))
      g.add(( res_audience_uri, RDFS.label , Literal(r.strip()) , vocab_graph ))

  # VOCAB: scope
  res_temporal = row["Scope: Temporal"]
  res_temporal_uri = URIRef(VOCAB+'temporal')
  res_geographical = row["Scope: Geographical"]
  res_geographical_uri = URIRef(VOCAB+'geographical')
  res_genre = row["Scope: Genre"]
  res_genre_uri = URIRef(VOCAB+'genre')
  res_artist = row["Scope: Artist"]
  res_artist_uri = URIRef(VOCAB+'artist')
			
  if res_temporal == 'Y':
    g.add(( res , SCHEMA.about , res_temporal_uri , g_name ))
    g.add(( res_temporal_uri, RDFS.label , Literal('Temporal') , g_name ))
    g.add(( res_temporal_uri, RDFS.label , Literal('Temporal') , vocab_graph ))
  if res_geographical == 'Y':
    g.add(( res , SCHEMA.about , res_geographical_uri , g_name ))
    g.add(( res_geographical_uri, RDFS.label , Literal('Geographical') , g_name ))
    g.add(( res_geographical_uri, RDFS.label , Literal('Geographical') , vocab_graph ))
  if res_genre == 'Y':
    g.add(( res , SCHEMA.about , res_genre_uri , g_name ))
    g.add(( res_genre_uri, RDFS.label , Literal('Genre') , g_name ))
    g.add(( res_genre_uri, RDFS.label , Literal('Genre') , vocab_graph ))    
  if res_artist == 'Y':
    g.add(( res , SCHEMA.about , res_artist_uri , g_name ))
    g.add(( res_artist_uri, RDFS.label , Literal('Composer') , g_name ))
    g.add(( res_artist_uri, RDFS.label , Literal('Composer') , vocab_graph )) 

  # VOCAB: subject 
  res_mo_type = row["Scope: MO type"]
  res_mo_type_label = camel_case_split(res_mo_type)
  mo_type_uri = URIRef(MO+res_mo_type)

  if len(res_mo_type):
    g.add(( res , SCHEMA.mainEntity , mo_type_uri , g_name ))
    g.add(( mo_type_uri, RDFS.label , Literal(res_mo_type_label) , g_name ))
    g.add(( mo_type_uri, RDFS.label , Literal(res_mo_type_label) , vocab_graph ))

  res_subject_type = row["Scope: Object type"]
  res_subject_type_id = "-".join([f.lower() for f in res_subject_type.split()])
  subject_type_uri = URIRef(VOCAB+res_subject_type_id)
  
  if len(res_subject_type) and res_subject_type in res_subject_types:
    g.add(( res , SCHEMA.mainEntity , subject_type_uri , g_name ))
    g.add(( subject_type_uri, RDFS.label , Literal(res_subject_type) , g_name ))
    g.add(( subject_type_uri, RDFS.label , Literal(res_subject_type) , vocab_graph ))
  
  # VOCAB: features http://schema.org/featureList
  res_interoperable = [row["Format: Interoperable?"], "Shares data in open data formats", URIRef(VOCAB+'interoperable')]
  res_human = [row["Interface: Human consumption?"], "Provides user-friendly interfaces", URIRef(VOCAB+'human-consumption')]
  res_playable = [row["Affordance: Is playable?"],"Offers playable music records", URIRef(VOCAB+'playable')]
  res_machine_readable = [row["Symbolic: Machine readable?"], "Serves machine-readable music data", URIRef(VOCAB+'machine-readable')]
  res_api = [row["Interface: API?"],"Offers a Web API",URIRef(VOCAB+'api')]
  res_sparql = [row["Interface: SPARQL endpoint?"],"Has a SPARQL endpoint",URIRef(VOCAB+'sparql-endpoint')]
  res_search = [row["Interface: Is it queryable?"],"Provides user-friendly search interfaces",URIRef(VOCAB+'search-interface')]
  res_browse = [row["Interface: Browsable?"], "Provides interfaces for browsing contents", URIRef(VOCAB+'browse-interface')]
  res_dump = [row["Interface: Data Dump?"],"Offers data export or dump",URIRef(VOCAB+'data-dump')]

  res_features = [res_interoperable,res_human,res_playable,res_machine_readable,res_api,res_sparql,res_search,res_browse,res_dump]
  for r in res_features:
    if r[0] == 'Y':
      g.add(( res , SCHEMA.featureList ,r[2] , g_name ))
      g.add(( r[2], RDFS.label , Literal(r[1]) , g_name ))
      g.add(( r[2], RDFS.label , Literal(r[1]) , vocab_graph ))

  # URI: example resource
  res_example = row["Item:Resource example"]
  if len(res_example):
    g.add(( res , SCHEMA.workExample , URIRef(res_example) , g_name ))

  # URI: based on 
  res_reused = row["Reused resource"]  
  if len(res_reused):
    resources = [f.strip() for f in res_reused.split(';')]
    for f in resources:
      # search for the index of the resource
      idx = df.index[df["ID: Resource name"] == f].tolist()
      res_reused_uri = URIRef(BASE+ids[idx[0]]) if len(idx) == 1 else URIRef(BASE+urid(f))
      g.add(( res , SCHEMA.isBasedOn , res_reused_uri , g_name ))
      g.add(( res_reused_uri, RDFS.label , Literal(f) , g_name ))

  # VOCAB: category  
  res_category = row["Category"]
  res_category_uri= URIRef(VOCAB+res_category.lower()) 
  if len(res_category):
    g.add(( res , SCHEMA.category ,res_category_uri , g_name ))
    g.add(( res_category_uri, RDFS.label , Literal(res_category) , g_name ))
    g.add(( res_category_uri, RDFS.label , Literal(res_category) , vocab_graph ))
  
  # VOCAB: music feature
  res_melody = [row["Feature: Melody"], "Melody", URIRef(VOCAB+'melody')]
  res_harmony = [row["Feature: Harmony"], "Harmony", URIRef(VOCAB+'harmony')]
  res_lyrics = [row["Feature: Lyrics"],"Lyrics", URIRef(VOCAB+'lyrics')]
  res_rhythm = [row["Feature: Rhythm"], "Rhythm",URIRef(VOCAB+'rhythm')]
  res_timbre = [row["Feature: Timbre"], "Timbre",URIRef(VOCAB+'timbre')]
  res_contour_shape = [row["Feature: Contour/Shape"], "Contour/Shape",URIRef(VOCAB+'contour-shape')]
  res_structure = [row["Feature: Structure"], "Music structure",URIRef(VOCAB+'structure')]
  res_metadata = [row["Feature: Descriptive Metadata"], "Descriptive Metadata",URIRef(VOCAB+'descriptive-metadata')]

  res_music_features = [res_melody,res_harmony,res_lyrics,res_rhythm,res_timbre,res_contour_shape,res_structure,res_metadata]
  for r in res_music_features:
    if r[0] == 'Y':
      g.add(( res , SCHEMA.keywords ,r[2] , g_name ))
      g.add(( r[2], RDFS.label , Literal(r[1]) , g_name ))
      g.add(( r[2], RDFS.label , Literal(r[1]) , vocab_graph ))

  # VOCAB: data format 
  res_format = row["Scope: Formats"]
  if len(res_format):
    formats = [f.strip().lower() for f in res_format.split(',')]
    for f in formats:
      g.add(( res , SCHEMA.encodingFormat ,URIRef(VOCAB+f) , g_name ))
      g.add(( URIRef(VOCAB+f), RDFS.label , Literal(f) , g_name ))
      g.add(( URIRef(VOCAB+f), RDFS.label , Literal(f) , vocab_graph ))
  
  # VOCAB: license 
  res_license = row["Access: license"]
  if len(res_license):
    res_license_uri = URIRef(VOCAB+res_license.strip().lower().replace(" ","-"))
    g.add(( res , SCHEMA.license ,res_license_uri , g_name ))
    g.add(( res_license_uri, RDFS.label , Literal(res_license) , g_name ))
    g.add(( res_license_uri, RDFS.label , Literal(res_license) , vocab_graph ))

  # URI: sparql endpoint 
  res_endpoint = row["SPARQL endpoint URI"]
  if len(res_endpoint):
    g.add(( res , URIRef("http://rdfs.org/ns/void#sparqlEndpoint") ,URIRef(res_endpoint) , g_name ))

  # VOCAB: collection size
  res_collection = row["Collection: Size"]
  res_collection_uri = URIRef(VOCAB+res_collection.lower().replace("<",'lt-').replace(">",'gt-'))
  if len(res_collection) and res_collection != 'N/A' and res_collection != 'UNKNOWN':
    g.add(( res , SCHEMA.collectionSize ,res_collection_uri , g_name ))
    g.add(( res_collection_uri, RDFS.label , Literal(res_collection) , g_name ))
    g.add(( res_collection_uri, RDFS.label , Literal(res_collection) , vocab_graph ))

  # VOCAB: content size
  res_content = row["Data size"]
  res_content_uri = URIRef(VOCAB+res_content.lower().replace("~",''))
  if len(res_content) and res_content != 'N/A' and res_content != 'UNKNOWN':
    g.add(( res , SCHEMA.contentSize ,res_content_uri , g_name ))
    g.add(( res_content_uri, RDFS.label , Literal(res_content) , g_name ))
    g.add(( res_content_uri, RDFS.label , Literal(res_content) , vocab_graph ))

  # VOCAB: task https://schema.org/specialty 
  res_task = row["Situation/Task"].split(';')
  if len(res_task) > 0:
    for r in res_task:
      res_task_uri = URIRef(VOCAB+r.strip().lower().replace(" ","-"))
      g.add(( res , SCHEMA.specialty , res_task_uri , g_name ))
      g.add(( res_task_uri, RDFS.label , Literal(r.strip()) , g_name ))
      g.add(( res_task_uri, RDFS.label , Literal(r.strip()) , vocab_graph ))


  # PROVENANCE 
  users = {"AM" : "albert.meronyo@gmail.com", 
           "ED": "enricodaga@gmail.com", 
           "MD": "marilena.daquino2@unibo.it"}

  # graph name
  g.add(( g_name , RDFS.label , Literal(res_title.strip()) , g_name ))

  # URI: creator
  res_creator = users[row["Person"]]
  res_creator_uri = URIRef(BASE+res_creator.replace('.','-dot-').replace('@', '-at-'))  
  g.add(( g_name, PROV.wasAttributedTo , res_creator_uri, g_name ))
  g.add(( res_creator_uri, RDFS.label , Literal(res_creator), g_name ))
  
  # STR: date
  date = Literal(datetime.now(),datatype=XSD.dateTime)
  g.add(( g_name, PROV.generatedAtTime , date, g_name ))
  
  # STR: publication stage
  g.add(( g_name, URIRef(BASE+"publicationStage") , Literal("published"), g_name ))  
  
# serialize graphs
g.serialize(format='trig',destination='records.trig',  encoding='utf-8' )

# download 
files.download('records.trig')
print(g.serialize(format='trig'))
# Out:
# @prefix musow: <https://w3id.org/musow/> .
# @prefix ns1: <http://www.w3.org/2002/07/owl#> .
# @prefix ns2: <http://rdfs.org/ns/void#> .
# @prefix prov: <http://www.w3.org/ns/prov#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix schema: <https://schema.org/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <https://w3id.org/musow/1635268063-598386/> {
#     <https://w3id.org/musow/1635268063-598386/> rdfs:label "MIREX" ;
#         prov:generatedAtTime "2021-10-26T17:07:44.627187"^^xsd:dateTime ;
#         prov:wasAttributedTo musow:marilena-dot-daquino2-at-unibo-dot-it ;
#         musow:publicationStage "published" .
#
#     <http://purl.org/ontology/mo/Signal> rdfs:label "Signal" .
#
#     musow:1635268063-598386 a schema:CreativeWork ;
#         rdfs:label "MIREX" ;
#         ns1:sameAs <http://data.open.ac.uk/musow/0179bf3894134d07caca0d2209bf5374> ;
#         schema:additionalType <https://w3id.org/musow/vocab/project> ;
#         schema:audience <https://w3id.org/musow/vocab/researchers> ;
#         schema:category <https://w3id.org/musow/vocab/media> ;
#         schema:creator musow:1635268063-598386 ;
#         schema:description "Music Information Retrieval Evaluation eXchange (MIREX). The International Music Information Retrieval Systems Evaluation Laboratory (IMIRSEL) at School of Information Sciences, University of Illinois at Urbana-Champaign (UIUC) is the principal organizer of MIREX." ;
#         schema:educationalUse <https://w3id.org/musow/vocab/research> ;
#         schema:featureList <https://w3id.org/musow/vocab/interoperable>,
#             <https://w3id.org/musow/vocab/machine-readable> ;
#         schema:keywords <https://w3id.org/musow/vocab/contour-shape>,
#             <https://w3id.org/musow/vocab/descriptive-metadata>,
#             <https://w3id.org/musow/vocab/harmony>,
#             <https://w3id.org/musow/vocab/lyrics>,
#             <https://w3id.org/musow/vocab/melody>,
#             <https://w3id.org/musow/vocab/rhythm>,
#             <https://w3id.org/musow/vocab/structure>,
#             <https://w3id.org/musow/vocab/timbre> ;
#         schema:license <https://w3id.org/musow/vocab/open-access> ;
#         schema:mainEntity <http://purl.org/ontology/mo/Signal>,
#             <https://w3id.org/musow/vocab/audio> ;
#         schema:mainEntityOfPage <http://www.music-ir.org/mirex/wiki/MIREX_HOME> ;
#         schema:name "MIREX" ;
#         schema:specialty <https://w3id.org/musow/vocab/audio-beat-tracking>,
#             <https://w3id.org/musow/vocab/audio-chord-estimation>,
#             <https://w3id.org/musow/vocab/audio-classification>,
#             <https://w3id.org/musow/vocab/audio-cover-song-identification>,
#             <https://w3id.org/musow/vocab/audio-downbeat-estimation>,
#             <https://w3id.org/musow/vocab/audio-fingerprinting>,
#             <https://w3id.org/musow/vocab/audio-key-detection>,
#             <https://w3id.org/musow/vocab/audio-melody-extraction>,
#             <https://w3id.org/musow/vocab/audio-music-similarity-and-retrieval>,
#             <https://w3id.org/musow/vocab/audio-offset-detection>,
#             <https://w3id.org/musow/vocab/audio-onset-detection>,
#             <https://w3id.org/musow/vocab/audio-tag-classification>,
#             <https://w3id.org/musow/vocab/audio-tempo-estimation>,
#             <https://w3id.org/musow/vocab/automatic-lyrics-to-audio-alignment>,
#             <https://w3id.org/musow/vocab/discovery-of-repeated-themes-&-sections>,
#             <https://w3id.org/musow/vocab/drum-transcription>,
#             <https://w3id.org/musow/vocab/multiple-fundamental-frequency-estimation-&-tracking>,
#             <https://w3id.org/musow/vocab/query-by-singing/humming>,
#             <https://w3id.org/musow/vocab/query-by-tapping>,
#             <https://w3id.org/musow/vocab/real-time-audio-to-score-alignment-(a.k.a-score-following)>,
#             <https://w3id.org/musow/vocab/set-list-identification>,
#             <https://w3id.org/musow/vocab/singing-voice-separation>,
#             <https://w3id.org/musow/vocab/structural-segmentation>,
#             <https://w3id.org/musow/vocab/symbolic-melodic-similarity> .
#
#     musow:marilena-dot-daquino2-at-unibo-dot-it rdfs:label "marilena.daquino2@unibo.it" .
#
#     <https://w3id.org/musow/vocab/audio> rdfs:label "Audio" .
#
#     <https://w3id.org/musow/vocab/audio-beat-tracking> rdfs:label "Audio Beat Tracking" .
#
#     <https://w3id.org/musow/vocab/audio-chord-estimation> rdfs:label "Audio Chord Estimation" .
#
#     <https://w3id.org/musow/vocab/audio-classification> rdfs:label "Audio classification" .
#
#     <https://w3id.org/musow/vocab/audio-cover-song-identification> rdfs:label "Audio Cover Song Identification" .
#
#     <https://w3id.org/musow/vocab/audio-downbeat-estimation> rdfs:label "Audio Downbeat Estimation" .
#
#     <https://w3id.org/musow/vocab/audio-fingerprinting> rdfs:label "Audio Fingerprinting" .
#
#     <https://w3id.org/musow/vocab/audio-key-detection> rdfs:label "Audio Key Detection" .
#
#     <https://w3id.org/musow/vocab/audio-melody-extraction> rdfs:label "Audio Melody Extraction" .
#
#     <https://w3id.org/musow/vocab/audio-music-similarity-and-retrieval> rdfs:label "Audio Music Similarity and Retrieval" .
#
#     <https://w3id.org/musow/vocab/audio-offset-detection> rdfs:label "Audio Offset Detection" .
#
#     <https://w3id.org/musow/vocab/audio-onset-detection> rdfs:label "Audio Onset Detection" .
#
#     <https://w3id.org/musow/vocab/audio-tag-classification> rdfs:label "Audio Tag Classification" .
#
#     <https://w3id.org/musow/vocab/audio-tempo-estimation> rdfs:label "Audio Tempo Estimation" .
#
#     <https://w3id.org/musow/vocab/automatic-lyrics-to-audio-alignment> rdfs:label "Automatic Lyrics-to-Audio Alignment" .
#
#     <https://w3id.org/musow/vocab/contour-shape> rdfs:label "Contour/Shape" .
#
#     <https://w3id.org/musow/vocab/descriptive-metadata> rdfs:label "Descriptive Metadata" .
#
#     <https://w3id.org/musow/vocab/discovery-of-repeated-themes-&-sections> rdfs:label "Discovery of Repeated Themes & Sections" .
#
#     <https://w3id.org/musow/vocab/drum-transcription> rdfs:label "Drum Transcription" .
#
#     <https://w3id.org/musow/vocab/harmony> rdfs:label "Harmony" .
#
#     <https://w3id.org/musow/vocab/interoperable> rdfs:label "Shares data in open data formats" .
#
#     <https://w3id.org/musow/vocab/lyrics> rdfs:label "Lyrics" .
#
#     <https://w3id.org/musow/vocab/machine-readable> rdfs:label "Serves machine-readable music data" .
#
#     <https://w3id.org/musow/vocab/media> rdfs:label "Media" .
#
#     <https://w3id.org/musow/vocab/melody> rdfs:label "Melody" .
#
#     <https://w3id.org/musow/vocab/multiple-fundamental-frequency-estimation-&-tracking> rdfs:label "Multiple Fundamental Frequency Estimation & Tracking" .
#
#     <https://w3id.org/musow/vocab/open-access> rdfs:label "Open Access" .
#
#     <https://w3id.org/musow/vocab/project> rdfs:label "Project" .
#
#     <https://w3id.org/musow/vocab/query-by-singing/humming> rdfs:label "Query by Singing/Humming" .
#
#     <https://w3id.org/musow/vocab/query-by-tapping> rdfs:label "Query by Tapping" .
#
#     <https://w3id.org/musow/vocab/real-time-audio-to-score-alignment-(a.k.a-score-following)> rdfs:label "Real-time Audio to Score Alignment (a.k.a Score Following)" .
#
#     <https://w3id.org/musow/vocab/research> rdfs:label "Research" .
#
#     <https://w3id.org/musow/vocab/researchers> rdfs:label "researchers" .
#
#     <https://w3id.org/musow/vocab/rhythm> rdfs:label "Rhythm" .
#
#     <https://w3id.org/musow/vocab/set-list-identification> rdfs:label "Set List Identification" .
#
#     <https://w3id.org/musow/vocab/singing-voice-separation> rdfs:label "Singing Voice Separation" .
#
#     <https://w3id.org/musow/vocab/structural-segmentation> rdfs:label "Structural Segmentation" .
#
#     <https://w3id.org/musow/vocab/structure> rdfs:label "Music structure" .
#
#     <https://w3id.org/musow/vocab/symbolic-melodic-similarity> rdfs:label "Symbolic Melodic Similarity" .
#
#     <https://w3id.org/musow/vocab/timbre> rdfs:label "Timbre" .
# }
#
# <https://w3id.org/musow/1635268063-603124/> {
#     <https://w3id.org/musow/1635268063-603124/> rdfs:label "LilyPond" ;
#         prov:generatedAtTime "2021-10-26T17:07:44.873801"^^xsd:dateTime ;
#         prov:wasAttributedTo musow:marilena-dot-daquino2-at-unibo-dot-it ;
#         musow:publicationStage "published" .
#
#     <http://purl.org/ontology/mo/Score> rdfs:label "Score" .
#
#     musow:1635268063-603124 a schema:CreativeWork ;
#         rdfs:label "LilyPond" ;
#         ns1:sameAs <http://data.open.ac.uk/musow/aa6601d96922d9fa84fd4def56597478> ;
#         schema:additionalType <https://w3id.org/musow/vocab/software> ;
#         schema:audience <https://w3id.org/musow/vocab/amateurs>,
#             <https://w3id.org/musow/vocab/performers>,
#             <https://w3id.org/musow/vocab/scholars> ;
#         schema:category <https://w3id.org/musow/vocab/symbolic> ;
#         schema:creator musow:1635268063-603124 ;
#         schema:description "Tool for annotating and rendering scores form a textual input" ;
#         schema:encodingFormat <https://w3id.org/musow/vocab/html>,
#             <https://w3id.org/musow/vocab/latex>,
#             <https://w3id.org/musow/vocab/lilypond>,
#             <https://w3id.org/musow/vocab/png> ;
#         schema:featureList <https://w3id.org/musow/vocab/browse-interface>,
#             <https://w3id.org/musow/vocab/human-consumption>,
#             <https://w3id.org/musow/vocab/interoperable>,
#             <https://w3id.org/musow/vocab/machine-readable> ;
#         schema:keywords <https://w3id.org/musow/vocab/harmony>,
#             <https://w3id.org/musow/vocab/lyrics>,
#             <https://w3id.org/musow/vocab/melody>,
#             <https://w3id.org/musow/vocab/rhythm> ;
#         schema:license <https://w3id.org/musow/vocab/gnu-gpl> ;
#         schema:mainEntity <http://purl.org/ontology/mo/Score> ;
#         schema:mainEntityOfPage <http://lilypond.org/> ;
#         schema:name "LilyPond" ;
#         schema:specialty <https://w3id.org/musow/vocab/data-visualization>,
#             <https://w3id.org/musow/vocab/music-annotation> ;
#         schema:workExample <http://lilypond.org/doc/v2.18/Documentation/notation/cheat-sheet> .
#
#     musow:marilena-dot-daquino2-at-unibo-dot-it rdfs:label "marilena.daquino2@unibo.it" .
#
#     <https://w3id.org/musow/vocab/amateurs> rdfs:label "amateurs" .
#
#     <https://w3id.org/musow/vocab/browse-interface> rdfs:label "Provides interfaces for browsing contents" .
#
#     <https://w3id.org/musow/vocab/data-visualization> rdfs:label "data visualization" .
#
#     <https://w3id.org/musow/vocab/gnu-gpl> rdfs:label "GNU-GPL" .
#
#     <https://w3id.org/musow/vocab/harmony> rdfs:label "Harmony" .
#
#     <https://w3id.org/musow/vocab/html> rdfs:label "html" .
#
#     <https://w3id.org/musow/vocab/human-consumption> rdfs:label "Provides user-friendly interfaces" .
#
#     <https://w3id.org/musow/vocab/interoperable> rdfs:label "Shares data in open data formats" .
#
#     <https://w3id.org/musow/vocab/latex> rdfs:label "latex" .
#
#     <https://w3id.org/musow/vocab/lilypond> rdfs:label "lilypond" .
#
#     <https://w3id.org/musow/vocab/lyrics> rdfs:label "Lyrics" .
#
#     <https://w3id.org/musow/vocab/machine-readable> rdfs:label "Serves machine-readable music data" .
#
#     <https://w3id.org/musow/vocab/melody> rdfs:label "Melody" .
#
#     <https://w3id.org/musow/vocab/music-annotation> rdfs:label "music annotation" .
#
#     <https://w3id.org/musow/vocab/performers> rdfs:label "performers" .
#
#     <https://w3id.org/musow/vocab/png> rdfs:label "png" .
#
#     <https://w3id.org/musow/vocab/rhythm> rdfs:label "Rhythm" .
#
#     <https://w3id.org/musow/vocab/scholars> rdfs:label "scholars" .
#
#     <https://w3id.org/musow/vocab/software> rdfs:label "Software" .
#
#     <https://w3id.org/musow/vocab/symbolic> rdfs:label "Symbolic" .
# }
#
# <https://w3id.org/musow/1635268063-580609/> {
#     <https://w3id.org/musow/1635268063-580609/> rdfs:label "RELICS (Renaissance Liturgical Imprints)" ;
#         prov:generatedAtTime "2021-10-26T17:07:43.696597"^^xsd:dateTime ;
#         prov:wasAttributedTo musow:marilena-dot-daquino2-at-unibo-dot-it ;
#         musow:publicationStage "published" .
#
#     <http://purl.org/ontology/mo/MusicalWork> rdfs:label "Musical Work" .
#
#     musow:1635268063-580609 a schema:CreativeWork ;
#         rdfs:label "RELICS (Renaissance Liturgical Imprints)" ;
#         ns1:sameAs <http://data.open.ac.uk/musow/d103a65c7ff87639de5d20048d66851a> ;
#         schema:about <https://w3id.org/musow/vocab/genre>,
#             <https://w3id.org/musow/vocab/temporal> ;
#         schema:additionalType <https://w3id.org/musow/vocab/catalogue> ;
#         schema:audience <https://w3id.org/musow/vocab/researchers> ;
#         schema:category <https://w3id.org/musow/vocab/metadata> ;
#         schema:collectionSize <https://w3id.org/musow/vocab/lt-100000> ;
#         schema:creator musow:1635268063-580609 ;
#         schema:description "This database, hosted at the University of Michigan, contains entries on c. 14,000 sources of liturgical music printed through the year 1600. Started by David Crawford (1995) and continued by James Borders, the database contains entries from publications in France, Germany, and many other European countries. Coverage extends to multiple Roman Catholic rites and to Protestant and Jewish liturgies." ;
#         schema:educationalUse <https://w3id.org/musow/vocab/research> ;
#         schema:featureList <https://w3id.org/musow/vocab/browse-interface>,
#             <https://w3id.org/musow/vocab/human-consumption>,
#             <https://w3id.org/musow/vocab/interoperable>,
#             <https://w3id.org/musow/vocab/search-interface> ;
#         schema:keywords <https://w3id.org/musow/vocab/descriptive-metadata> ;
#         schema:license <https://w3id.org/musow/vocab/open-access> ;
#         schema:mainEntity <http://purl.org/ontology/mo/MusicalWork>,
#             <https://w3id.org/musow/vocab/musical-resource> ;
#         schema:mainEntityOfPage <http://quod.lib.umich.edu/r/relics> ;
#         schema:name "RELICS (Renaissance Liturgical Imprints)" ;
#         schema:specialty <https://w3id.org/musow/vocab/music-history>,
#             <https://w3id.org/musow/vocab/musicology> ;
#         schema:workExample <http://quod.lib.umich.edu/cgi/b/bib/bib-idx?type=simple&c=relics&sid=5ab64c16d9b33cd12556745d9802cc9a&q1=LAUDE&rgn1=title&cc=relics&view=reslist&sort=Title&page=reslist&start=1&size=10&fmt=long> .
#
#     musow:marilena-dot-daquino2-at-unibo-dot-it rdfs:label "marilena.daquino2@unibo.it" .
#
#     <https://w3id.org/musow/vocab/browse-interface> rdfs:label "Provides interfaces for browsing contents" .
#
#     <https://w3id.org/musow/vocab/catalogue> rdfs:label "Catalogue" .
#
#     <https://w3id.org/musow/vocab/descriptive-metadata> rdfs:label "Descriptive Metadata" .
#
#     <https://w3id.org/musow/vocab/genre> rdfs:label "Genre" .
#
#     <https://w3id.org/musow/vocab/human-consumption> rdfs:label "Provides user-friendly interfaces" .
#
#     <https://w3id.org/musow/vocab/interoperable> rdfs:label "Shares data in open data formats" .
#
#     <https://w3id.org/musow/vocab/lt-100000> rdfs:label "<100000" .
#
#     <https://w3id.org/musow/vocab/metadata> rdfs:label "Metadata" .
#
#     <https://w3id.org/musow/vocab/music-history> rdfs:label "music history" .
#
#     <https://w3id.org/musow/vocab/musical-resource> rdfs:label "Musical resource" .
#
#     <https://w3id.org/musow/vocab/musicology> rdfs:label "musicology" .
#
#     <https://w3id.org/musow/vocab/open-access> rdfs:label "Open Access" .
#
#     <https://w3id.org/musow/vocab/research> rdfs:label "Research" .
#
#     <https://w3id.org/musow/vocab/researchers> rdfs:label "researchers" .
#
#     <https://w3id.org/musow/vocab/search-interface> rdfs:label "Provides user-friendly search interfaces" .
#
#     <https://w3id.org/musow/vocab/temporal> rdfs:label "Temporal" .
# }
#
# <https://w3id.org/musow/1635268063-600716/> {
#     <https://w3id.org/musow/1635268063-600716/> rdfs:label "Conductus: Online catalogue of poetry and musical settings" ;
#         prov:generatedAtTime "2021-10-26T17:07:44.757082"^^xsd:dateTime ;
#         prov:wasAttributedTo musow:marilena-dot-daquino2-at-unibo-dot-it ;
#         musow:publicationStage "published" .
#
#     <http://purl.org/ontology/mo/Score> rdfs:label "Score" .
#
#     musow:1635268063-600716 a schema:CreativeWork ;
#         rdfs:label "Conductus: Online catalogue of poetry and musical settings" ;
#         ns1:sameAs <http://data.open.ac.uk/musow/32b112bf56d939665b8d25a8a9c1e5be> ;
#         schema:about <https://w3id.org/musow/vocab/genre> ;
#         schema:additionalType <https://w3id.org/musow/vocab/repository> ;
#         schema:audience <https://w3id.org/musow/vocab/researchers> ;
#         schema:category <https://w3id.org/musow/vocab/symbolic> ;
#         schema:collectionSize <https://w3id.org/musow/vocab/lt-1000> ;
#         schema:creator musow:1635268063-600716 ;
#         schema:description "Mark Everist's conductus catalogue, officially called CPI (Cantus pulcriorem invenire), contains 866 works found in 547 sources (start of 2015). It facilitates search by title, source, form, style of setting, stanza, poet, language, poetic structure (several subfields), and terminal accent. Sources listed are digitized and viewable online. Cross-listed to DIAMM and RISM." ;
#         schema:educationalUse <https://w3id.org/musow/vocab/research> ;
#         schema:featureList <https://w3id.org/musow/vocab/browse-interface>,
#             <https://w3id.org/musow/vocab/human-consumption>,
#             <https://w3id.org/musow/vocab/interoperable>,
#             <https://w3id.org/musow/vocab/machine-readable>,
#             <https://w3id.org/musow/vocab/search-interface> ;
#         schema:keywords <https://w3id.org/musow/vocab/descriptive-metadata>,
#             <https://w3id.org/musow/vocab/lyrics>,
#             <https://w3id.org/musow/vocab/structure> ;
#         schema:license <https://w3id.org/musow/vocab/open-access> ;
#         schema:mainEntity <http://purl.org/ontology/mo/Score> ;
#         schema:mainEntityOfPage <http://catalogue.conductus.ac.uk/> ;
#         schema:name "Conductus: Online catalogue of poetry and musical settings" ;
#         schema:specialty <https://w3id.org/musow/vocab/comparative-studies>,
#             <https://w3id.org/musow/vocab/music-history>,
#             <https://w3id.org/musow/vocab/musicology> .
#
#     musow:marilena-dot-daquino2-at-unibo-dot-it rdfs:label "marilena.daquino2@unibo.it" .
#
#     <https://w3id.org/musow/vocab/browse-interface> rdfs:label "Provides interfaces for browsing contents" .
#
#     <https://w3id.org/musow/vocab/comparative-studies> rdfs:label "comparative studies" .
#
#     <https://w3id.org/musow/vocab/descriptive-metadata> rdfs:label "Descriptive Metadata" .
#
#     <https://w3id.org/musow/vocab/genre> rdfs:label "Genre" .
#
#     <https://w3id.org/musow/vocab/human-consumption> rdfs:label "Provides user-friendly interfaces" .
#
#     <https://w3id.org/musow/vocab/interoperable> rdfs:label "Shares data in open data formats" .
#
#     <https://w3id.org/musow/vocab/lt-1000> rdfs:label "<1000" .
#
#     <https://w3id.org/musow/vocab/lyrics> rdfs:label "Lyrics" .
#
#     <https://w3id.org/musow/vocab/machine-readable> rdfs:label "Serves machine-readable music data" .
#
#     <https://w3id.org/musow/vocab/music-history> rdfs:label "music history" .
#
#     <https://w3id.org/musow/vocab/musicology> rdfs:label "musicology" .
#
#     <https://w3id.org/musow/vocab/open-access> rdfs:label "Open Access" .
#
#     <https://w3id.org/musow/vocab/repository> rdfs:label "Repository" .
#
#     <https://w3id.org/musow/vocab/research> rdfs:label "Research" .
#
#     <https://w3id.org/musow/vocab/researchers> rdfs:label "researchers" .
#
#     <https://w3id.org/musow/vocab/search-interface> rdfs:label "Provides user-friendly search interfaces" .
#
#     <https://w3id.org/musow/vocab/structure> rdfs:label "Music structure" .
#
#     <https://w3id.org/musow/vocab/symbolic> rdfs:label "Symbolic" .
# }
#
# <https://w3id.org/musow/1635268063-589753/> {
#     <https://w3id.org/musow/1635268063-589753/> rdfs:label "Musical Scores from the University of Illinois Music Library" ;
#         prov:generatedAtTime "2021-10-26T17:07:44.151400"^^xsd:dateTime ;
#         prov:wasAttributedTo musow:marilena-dot-daquino2-at-unibo-dot-it ;
#         musow:publicationStage "published" .
#
#     <http://purl.org/ontology/mo/Score> rdfs:label "Score" .
#
#     musow:1635268063-589753 a schema:CreativeWork ;
#         rdfs:label "Musical Scores from the University of Illinois Music Library" ;
#         ns1:sameAs <http://data.open.ac.uk/musow/e2ba10a0d77319fe4b360ca9a927f044> ;
#         schema:about <https://w3id.org/musow/vocab/geographical> ;
#         schema:additionalType <https://w3id.org/musow/vocab/repository> ;
#         schema:audience <https://w3id.org/musow/vocab/researchers> ;
#         schema:category <https://w3id.org/musow/vocab/symbolic> ;
#         schema:collectionSize <https://w3id.org/musow/vocab/lt-100> ;
#         schema:contentSize <https://w3id.org/musow/vocab/gb> ;
#         schema:creator musow:1635268063-589753 ;
#         schema:description "Musical theatre and operetta scores from the Music and Performing Arts Library Special Collections." ;
#         schema:educationalUse <https://w3id.org/musow/vocab/research> ;
#         schema:encodingFormat <https://w3id.org/musow/vocab/marcxml>,
#             <https://w3id.org/musow/vocab/pdf> ;
#         schema:featureList <https://w3id.org/musow/vocab/api>,
#             <https://w3id.org/musow/vocab/browse-interface>,
#             <https://w3id.org/musow/vocab/data-dump>,
#             <https://w3id.org/musow/vocab/human-consumption>,
#             <https://w3id.org/musow/vocab/interoperable>,
#             <https://w3id.org/musow/vocab/search-interface> ;
#         schema:keywords <https://w3id.org/musow/vocab/descriptive-metadata> ;
#         schema:license <https://w3id.org/musow/vocab/open-access> ;
#         schema:mainEntity <http://purl.org/ontology/mo/Score> ;
#         schema:mainEntityOfPage <http://www.uiuc.edu/goto/music> ;
#         schema:name "Musical Scores from the University of Illinois Music Library" ;
#         schema:specialty <https://w3id.org/musow/vocab/music-history>,
#             <https://w3id.org/musow/vocab/musicology> ;
#         schema:workExample <https://archive.org/details/greekslavemusica00jones> .
#
#     musow:marilena-dot-daquino2-at-unibo-dot-it rdfs:label "marilena.daquino2@unibo.it" .
#
#     <https://w3id.org/musow/vocab/api> rdfs:label "Offers a Web API" .
#
#     <https://w3id.org/musow/vocab/browse-interface> rdfs:label "Provides interfaces for browsing contents" .
#
#     <https://w3id.org/musow/vocab/data-dump> rdfs:label "Offers data export or dump" .
#
#     <https://w3id.org/musow/vocab/descriptive-metadata> rdfs:label "Descriptive Metadata" .
#
#     <https://w3id.org/musow/vocab/gb> rdfs:label "~Gb" .
#
#     <https://w3id.org/musow/vocab/geographical> rdfs:label "Geographical" .
#
#     <https://w3id.org/musow/vocab/human-consumption> rdfs:label "Provides user-friendly interfaces" .
#
#     <https://w3id.org/musow/vocab/interoperable> rdfs:label "Shares data in open data formats" .
#
#     <https://w3id.org/musow/vocab/lt-100> rdfs:label "<100" .
#
#     <https://w3id.org/musow/vocab/marcxml> rdfs:label "marcxml" .
#
#     <https://w3id.org/musow/vocab/music-history> rdfs:label "music history" .
#
#     <https://w3id.org/musow/vocab/musicology> rdfs:label "musicology" .
#
#     <https://w3id.org/musow/vocab/open-access> rdfs:label "Open Access" .
#
#     <https://w3id.org/musow/vocab/pdf> rdfs:label "pdf" .
#
#     <https://w3id.org/musow/vocab/repository> rdfs:label "Repository" .
#
#     <https://w3id.org/musow/vocab/research> rdfs:label "Research" .
#
#     <https://w3id.org/musow/vocab/researchers> rdfs:label "researchers" .
#
#     <https://w3id.org/musow/vocab/search-interface> rdfs:label "Provides user-friendly search interfaces" .
#
#     <https://w3id.org/musow/vocab/symbolic> rdfs:label "Symbolic" .
# }
#
# <https://w3id.org/musow/1635268063-589825/> {
#     <https://w3id.org/musow/1635268063-589825/> rdfs:label "Muziekschatten: Online Bladmuziekcollectie (Music Treasures: Online Sheet Music Collection)" ;
#         prov:generatedAtTime "2021-10-26T17:07:44.153800"^^xsd:dateTime ;
#         prov:wasAttributedTo musow:marilena-dot-daquino2-at-unibo-dot-it ;
#         musow:publicationStage "published" .
#
#     <http://purl.org/ontology/mo/MusicalWork> rdfs:label "Musical Work" .
#
#     musow:1635268063-589825 a schema:CreativeWork ;
#         rdfs:label "Muziekschatten: Online Bladmuziekcollectie (Music Treasures: Online Sheet Music Collection)" ;
#         ns1:sameAs <http://data.open.ac.uk/musow/7a57553f7c4f73c0745b97df6564a702> ;
#         schema:additionalType <https://w3id.org/musow/vocab/repository> ;
#         schema:audience <https://w3id.org/musow/vocab/amateurs> ;
#         schema:category <https://w3id.org/musow/vocab/media> ;
#         schema:collectionSize <https://w3id.org/musow/vocab/lt-10000> ;
#         schema:creator musow:1635268063-589825 ;
#         schema:description "A selection of over 5000 musical works from the Netherlands Radio Music Library, including unpublished works by Dutch composers commissioned by broadcasters, rare foreign publications from the period, choral music, chamber music, popular songs, popular music arranged for radio ensembles and radio and television jingles." ;
#         schema:featureList <https://w3id.org/musow/vocab/human-consumption>,
#             <https://w3id.org/musow/vocab/playable> ;
#         schema:license <https://w3id.org/musow/vocab/copyright> ;
#         schema:mainEntity <http://purl.org/ontology/mo/MusicalWork>,
#             <https://w3id.org/musow/vocab/audio> ;
#         schema:mainEntityOfPage <http://www.muziekschatten.nl/> ;
#         schema:name "Muziekschatten: Online Bladmuziekcollectie (Music Treasures: Online Sheet Music Collection)" ;
#         schema:specialty <https://w3id.org/musow/vocab/music-listening> .
#
#     musow:marilena-dot-daquino2-at-unibo-dot-it rdfs:label "marilena.daquino2@unibo.it" .
#
#     <https://w3id.org/musow/vocab/amateurs> rdfs:label "amateurs" .
#
#     <https://w3id.org/musow/vocab/audio> rdfs:label "Audio" .
#
#     <https://w3id.org/musow/vocab/copyright> rdfs:label "Copyright" .
#
#     <https://w3id.org/musow/vocab/human-consumption> rdfs:label "Provides user-friendly interfaces" .
#
#     <https://w3id.org/musow/vocab/lt-10000> rdfs:label "<10000" .
#
#     <https://w3id.org/musow/vocab/media> rdfs:label "Media" .
#
#     <https://w3id.org/musow/vocab/music-listening> rdfs:label "music listening" .
#
#     <https://w3id.org/musow/vocab/playable> rdfs:label "Offers playable music records" .
#
#     <https://w3id.org/musow/vocab/repository> rdfs:label "Repository" .
# }
#
# <https://w3id.org/musow/1635268063-596449/> {
#     musow:1635268063-596449 a schema:CreativeWork ;
#         rdfs:label "CALMA Dataset" ;
#         ns2:sparqlEndpoint <http://etree.linkedmusic.org/sparql> ;
#         ns1:sameAs <http://data.open.ac.uk/musow/f3947092c3744fe0c753a8f64fa2652c> ;
#         schema:additionalType <https://w3id.org/musow/vocab/dataset> ;
#         schema:audience <https://w3id.org/musow/vocab/researchers> ;
#         schema:category <https://w3id.org/musow/vocab/media> ;
#         schema:collectionSize <https://w3id.org/musow/vocab/gt-1m> ;
#         schema:contentSize <https://w3id.org/musow/vocab/gb> ;
#         schema:creator musow:aa8b8436ad51741787d1281fa6dc5b32 ;
#         schema:description "The CALMA project aims to extend the etree metadata with results of computational analysis of audio files. Metadata and raw analysis results are published on the http://calma.linkedmusic.org/data server along with detailed information about the provenance of the analysis results. Links to the analysis data are also provided from the original etree data set." ;
#         schema:educationalUse <https://w3id.org/musow/vocab/research> ;
#         schema:encodingFormat <https://w3id.org/musow/vocab/flac>,
#             <https://w3id.org/musow/vocab/mp3>,
#             <https://w3id.org/musow/vocab/rdf> ;
#         schema:featureList <https://w3id.org/musow/vocab/browse-interface>,
#             <https://w3id.org/musow/vocab/data-dump>,
#             <https://w3id.org/musow/vocab/human-consumption>,
#             <https://w3id.org/musow/vocab/interoperable>,
#             <https://w3id.org/musow/vocab/machine-readable>,
#             <https://w3id.org/musow/vocab/playable>,
#             <https://w3id.org/musow/vocab/sparql-endpoint> ;
#         schema:isBasedOn musow:1635268063-581794,
#             musow:1635268063-58566,
#             musow:1635268063-585805,
#             musow:1635268063-59824,
#             musow:79cc3b660ea08cebb9e39be95b381706,
#             musow:873000a32eb6dcd4fcd14e86f0b28f8a,
#             musow:b06a4990190f6d941569b4af46380b2d ;
#         schema:keywords <https://w3id.org/musow/vocab/contour-shape>,
#             <https://w3id.org/musow/vocab/descriptive-metadata>,
#             <https://w3id.org/musow/vocab/harmony>,
#             <https://w3id.org/musow/vocab/lyrics>,
#             <https://w3id.org/musow/vocab/melody>,
#             <https://w3id.org/musow/vocab/rhythm>,
#             <https://w3id.org/musow/vocab/structure>,
#             <https://w3id.org/musow/vocab/timbre> ;
#         schema:license <https://w3id.org/musow/vocab/cc0> ;
#         schema:mainEntity <http://purl.org/ontology/mo/Signal>,
#             <https://w3id.org/musow/vocab/audio> ;
#         schema:mainEntityOfPage <http://calma.linkedmusic.org/> ;
#         schema:name "CALMA Dataset" ;
#         schema:specialty <https://w3id.org/musow/vocab/music-analysis>,
#             <https://w3id.org/musow/vocab/music-information-retrieval>,
#             <https://w3id.org/musow/vocab/musicology> ;
#         schema:workExample <http://etree.linkedmusic.org/page/track/DBT2004-11-26.flac16-4> .
#
#     <https://w3id.org/musow/1635268063-596449/> rdfs:label "CALMA Dataset" ;
#         prov:generatedAtTime "2021-10-26T17:07:44.447328"^^xsd:dateTime ;
#         prov:wasAttributedTo musow:marilena-dot-daquino2-at-unibo-dot-it ;
#         musow:publicationStage "published" .
#
#     <http://purl.org/ontology/mo/Signal> rdfs:label "Signal" .
#
#     musow:1635268063-581794 rdfs:label "LinkedBrainz" .
#
#     musow:1635268063-58566 rdfs:label "Music Ontology" .
#
#     musow:1635268063-585805 rdfs:label "Etree Vocabulary" .
#
#     musow:1635268063-59824 rdfs:label "CALMA Vocabulary" .
#
#     musow:79cc3b660ea08cebb9e39be95b381706 rdfs:label "Event Ontology" .
#
#     musow:873000a32eb6dcd4fcd14e86f0b28f8a rdfs:label "Similarity Ontology" .
#
#     musow:aa8b8436ad51741787d1281fa6dc5b32 rdfs:label "Live Music Archive Linked Data (LMA)" .
#
#     musow:b06a4990190f6d941569b4af46380b2d rdfs:label "Last.fm" .
#
#     musow:marilena-dot-daquino2-at-unibo-dot-it rdfs:label "marilena.daquino2@unibo.it" .
#
#     <https://w3id.org/musow/vocab/audio> rdfs:label "Audio" .
#
#     <https://w3id.org/musow/vocab/browse-interface> rdfs:label "Provides interfaces for browsing contents" .
#
#     <https://w3id.org/musow/vocab/cc0> rdfs:label "CC0" .
#
#     <https://w3id.org/musow/vocab/contour-shape> rdfs:label "Contour/Shape" .
#
#     <https://w3id.org/musow/vocab/data-dump> rdfs:label "Offers data export or dump" .
#
#     <https://w3id.org/musow/vocab/dataset> rdfs:label "Dataset" .
#
#     <https://w3id.org/musow/vocab/descriptive-metadata> rdfs:label "Descriptive Metadata" .
#
#     <https://w3id.org/musow/vocab/flac> rdfs:label "flac" .
#
#     <https://w3id.org/musow/vocab/gb> rdfs:label "~Gb" .
#
#     <https://w3id.org/musow/vocab/gt-1m> rdfs:label ">1M" .
#
#     <https://w3id.org/musow/vocab/harmony> rdfs:label "Harmony" .
#
#     <https://w3id.org/musow/vocab/human-consumption> rdfs:label "Provides user-friendly interfaces" .
#
#     <https://w3id.org/musow/vocab/interoperable> rdfs:label "Shares data in open data formats" .
#
#     <https://w3id.org/musow/vocab/lyrics> rdfs:label "Lyrics" .
#
#     <https://w3id.org/musow/vocab/machine-readable> rdfs:label "Serves machine-readable music data" .
#
#     <https://w3id.org/musow/vocab/media> rdfs:label "Media" .
#
#     <https://w3id.org/musow/vocab/melody> rdfs:label "Melody" .
#
#     <https://w3id.org/musow/vocab/mp3> rdfs:label "mp3" .
#
#     <https://w3id.org/musow/vocab/music-analysis> rdfs:label "music analysis" .
#
#     <https://w3id.org/musow/vocab/music-information-retrieval> rdfs:label "music information retrieval" .
#
#     <https://w3id.org/musow/vocab/musicology> rdfs:label "musicology" .
#
#     <https://w3id.org/musow/vocab/playable> rdfs:label "Offers playable music records" .
#
#     <https://w3id.org/musow/vocab/rdf> rdfs:label "rdf" .
#
#     <https://w3id.org/musow/vocab/research> rdfs:label "Research" .
#
#     <https://w3id.org/musow/vocab/researchers> rdfs:label "researchers" .
#
#     <https://w3id.org/musow/vocab/rhythm> rdfs:label "Rhythm" .
#
#     <https://w3id.org/musow/vocab/sparql-endpoint> rdfs:label "Has a SPARQL endpoint" .
#
#     <https://w3id.org/musow/vocab/structure> rdfs:label "Music structure" .
#
#     <https://w3id.org/musow/vocab/timbre> rdfs:label "Timbre" .
# }
#
# <https://w3id.org/musow/1635268063-579102/> {
#     <https://w3id.org/musow/1635268063-579102/> rdfs:label "Arto Wikla's Early Music Pages" ;
#         prov:generatedAtTime "2021-10-26T17:07:43.632317"^^xsd:dateTime ;
#         prov:wasAttributedTo musow:marilena-dot-daquino2-at-unibo-dot-it ;
#         musow:publicationStage "published" .
#
#     <http://purl.org/ontology/mo/MusicalWork> rdfs:label "Musical Work" .
#
#     musow:1635268063-579102 a schema:CreativeWork ;
#         rdfs:label "Arto Wikla's Early Music Pages" ;
#         ns1:sameAs <http://data.open.ac.uk/musow/30afbfe558c40e34d70ef110cea793f8> ;
#         schema:about <https://w3id.org/musow/vocab/genre>,
#             <https://w3id.org/musow/vocab/temporal> ;
#         schema:additionalType <https://w3id.org/musow/vocab/catalogue> ;
#         schema:audience <https://w3id.org/musow/vocab/researchers> ;
#         schema:category <https://w3id.org/musow/vocab/metadata> ;
#         schema:collectionSize <https://w3id.org/musow/vocab/lt-1000> ;
#         schema:contentSize <https://w3id.org/musow/vocab/mb> ;
#         schema:creator musow:1635268063-579102 ;
#         schema:description "A list of websites about early music, with a focus on instrumental music; features transcriptions of lute and theorbo pieces." ;
#         schema:educationalUse <https://w3id.org/musow/vocab/research> ;
#         schema:featureList <https://w3id.org/musow/vocab/browse-interface>,
#             <https://w3id.org/musow/vocab/human-consumption>,
#             <https://w3id.org/musow/vocab/interoperable> ;
#         schema:keywords <https://w3id.org/musow/vocab/descriptive-metadata> ;
#         schema:license <https://w3id.org/musow/vocab/open-access> ;
#         schema:mainEntity <http://purl.org/ontology/mo/MusicalWork>,
#             <https://w3id.org/musow/vocab/musical-resource> ;
#         schema:mainEntityOfPage <http://www.cs.helsinki.fi/~wikla/music.html> ;
#         schema:name "Arto Wikla's Early Music Pages" ;
#         schema:specialty <https://w3id.org/musow/vocab/music-history>,
#             <https://w3id.org/musow/vocab/musicology> .
#
#     musow:marilena-dot-daquino2-at-unibo-dot-it rdfs:label "marilena.daquino2@unibo.it" .
#
#     <https://w3id.org/musow/vocab/browse-interface> rdfs:label "Provides interfaces for browsing contents" .
#
#     <https://w3id.org/musow/vocab/catalogue> rdfs:label "Catalogue" .
#
#     <https://w3id.org/musow/vocab/descriptive-metadata> rdfs:label "Descriptive Metadata" .
#
#     <https://w3id.org/musow/vocab/genre> rdfs:label "Genre" .
#
#     <https://w3id.org/musow/vocab/human-consumption> rdfs:label "Provides user-friendly interfaces" .
#
#     <https://w3id.org/musow/vocab/interoperable> rdfs:label "Shares data in open data formats" .
#
#     <https://w3id.org/musow/vocab/lt-1000> rdfs:label "<1000" .
#
#     <https://w3id.org/musow/vocab/mb> rdfs:label "~Mb" .
#
#     <https://w3id.org/musow/vocab/metadata> rdfs:label "Metadata" .
#
#     <https://w3id.org/musow/vocab/music-history> rdfs:label "music history" .
#
#     <https://w3id.org/musow/vocab/musical-resource> rdfs:label "Musical resource" .
#
#     <https://w3id.org/musow/vocab/musicology> rdfs:label "musicology" .
#
#     <https://w3id.org/musow/vocab/open-access> rdfs:label "Open Access" .
#
#     <https://w3id.org/musow/vocab/research> rdfs:label "Research" .
#
#     <https://w3id.org/musow/vocab/researchers> rdfs:label "researchers" .
#
#     <https://w3id.org/musow/vocab/temporal> rdfs:label "Temporal" .
# }
#
# <https://w3id.org/musow/1635268063-602581/> {
#     musow:1635268063-602581 a schema:CreativeWork ;
#         rdfs:label "Aruspix" ;
#         ns1:sameAs <http://data.open.ac.uk/musow/063d37124e6d81db1701e591e84a12e5> ;
#         schema:additionalType <https://w3id.org/musow/vocab/software> ;
#         schema:audience <https://w3id.org/musow/vocab/researchers> ;
#         schema:category <https://w3id.org/musow/vocab/symbolic> ;
#         schema:creator musow:15bc7c8969715a1ffd0097f15e616161 ;
#         schema:description "With its optical recognition feature, Aruspix acts as a unique music scanning software for early music prints. Aruspix also has the particularity that it learns and improves itself dynamically as soon as a page is processed and corrected by the user." ;
#         schema:educationalUse <https://w3id.org/musow/vocab/research> ;
#         schema:encodingFormat <https://w3id.org/musow/vocab/jpg>,
#             <https://w3id.org/musow/vocab/mei/xml> ;
#         schema:featureList <https://w3id.org/musow/vocab/browse-interface>,
#             <https://w3id.org/musow/vocab/human-consumption>,
#             <https://w3id.org/musow/vocab/interoperable>,
#             <https://w3id.org/musow/vocab/machine-readable> ;
#         schema:isBasedOn musow:1635268063-601321 ;
#         schema:keywords <https://w3id.org/musow/vocab/descriptive-metadata>,
#             <https://w3id.org/musow/vocab/harmony>,
#             <https://w3id.org/musow/vocab/lyrics>,
#             <https://w3id.org/musow/vocab/melody>,
#             <https://w3id.org/musow/vocab/rhythm> ;
#         schema:license <https://w3id.org/musow/vocab/open-access> ;
#         schema:mainEntity <http://purl.org/ontology/mo/Score> ;
#         schema:mainEntityOfPage <http://www.aruspix.net/> ;
#         schema:name "Aruspix" ;
#         schema:specialty <https://w3id.org/musow/vocab/music-philology> ;
#         schema:workExample <https://marenzio.cdrs.columbia.edu/digital-edition/M-01-5-07.xhtml> .
#
#     <https://w3id.org/musow/1635268063-602581/> rdfs:label "Aruspix" ;
#         prov:generatedAtTime "2021-10-26T17:07:44.848325"^^xsd:dateTime ;
#         prov:wasAttributedTo musow:marilena-dot-daquino2-at-unibo-dot-it ;
#         musow:publicationStage "published" .
#
#     <http://purl.org/ontology/mo/Score> rdfs:label "Score" .
#
#     musow:15bc7c8969715a1ffd0097f15e616161 rdfs:label "Marenzio Project" .
#
#     musow:1635268063-601321 rdfs:label "MEI XML schema" .
#
#     musow:marilena-dot-daquino2-at-unibo-dot-it rdfs:label "marilena.daquino2@unibo.it" .
#
#     <https://w3id.org/musow/vocab/browse-interface> rdfs:label "Provides interfaces for browsing contents" .
#
#     <https://w3id.org/musow/vocab/descriptive-metadata> rdfs:label "Descriptive Metadata" .
#
#     <https://w3id.org/musow/vocab/harmony> rdfs:label "Harmony" .
#
#     <https://w3id.org/musow/vocab/human-consumption> rdfs:label "Provides user-friendly interfaces" .
#
#     <https://w3id.org/musow/vocab/interoperable> rdfs:label "Shares data in open data formats" .
#
#     <https://w3id.org/musow/vocab/jpg> rdfs:label "jpg" .
#
#     <https://w3id.org/musow/vocab/lyrics> rdfs:label "Lyrics" .
#
#     <https://w3id.org/musow/vocab/machine-readable> rdfs:label "Serves machine-readable music data" .
#
#     <https://w3id.org/musow/vocab/mei/xml> rdfs:label "mei/xml" .
#
#     <https://w3id.org/musow/vocab/melody> rdfs:label "Melody" .
#
#     <https://w3id.org/musow/vocab/music-philology> rdfs:label "music philology" .
#
#     <https://w3id.org/musow/vocab/open-access> rdfs:label "Open Access" .
#
#     <https://w3id.org/musow/vocab/research> rdfs:label "Research" .
#
#     <https://w3id.org/musow/vocab/researchers> rdfs:label "researchers" .
#
#     <https://w3id.org/musow/vocab/rhythm> rdfs:label "Rhythm" .
#
#     <https://w3id.org/musow/vocab/software> rdfs:label "Software" .
#
#     <https://w3id.org/musow/vocab/symbolic> rdfs:label "Symbolic" .
# }
#
# <https://w3id.org/musow/1635268063-595771/> {
#     musow:1635268063-595771 a schema:CreativeWork ;
#         rdfs:label "Cantus Manuscript Database" ;
#         ns1:sameAs <http://data.open.ac.uk/musow/4c41c0f770b8c4cf903095cd2c1e744f> ;
#         schema:about <https://w3id.org/musow/vocab/genre>,
#             <https://w3id.org/musow/vocab/geographical>,
#             <https://w3id.org/musow/vocab/temporal> ;
#         schema:additionalType <https://w3id.org/musow/vocab/dataset> ;
#         schema:audience <https://w3id.org/musow/vocab/researchers> ;
#         schema:category <https://w3id.org/musow/vocab/symbolic> ;
#         schema:collectionSize <https://w3id.org/musow/vocab/lt-1000> ;
#         schema:creator musow:6b6f0f012cc638cd7a6c26f5fef91d21 ;
#         schema:description "Database of latin chants and melody search engine" ;
#         schema:educationalUse <https://w3id.org/musow/vocab/research> ;
#         schema:encodingFormat <https://w3id.org/musow/vocab/jpg> ;
#         schema:featureList <https://w3id.org/musow/vocab/browse-interface>,
#             <https://w3id.org/musow/vocab/human-consumption>,
#             <https://w3id.org/musow/vocab/interoperable>,
#             <https://w3id.org/musow/vocab/machine-readable>,
#             <https://w3id.org/musow/vocab/search-interface> ;
#         schema:isBasedOn musow:1635268063-601466,
#             musow:1635268063-602125 ;
#         schema:keywords <https://w3id.org/musow/vocab/descriptive-metadata>,
#             <https://w3id.org/musow/vocab/lyrics>,
#             <https://w3id.org/musow/vocab/melody>,
#             <https://w3id.org/musow/vocab/structure> ;
#         schema:license <https://w3id.org/musow/vocab/cc-by-nc-sa> ;
#         schema:mainEntity <http://purl.org/ontology/mo/Score> ;
#         schema:mainEntityOfPage <http://cantus.uwaterloo.ca/> ;
#         schema:name "Cantus Manuscript Database" ;
#         schema:specialty <https://w3id.org/musow/vocab/data-visualization> ;
#         schema:workExample <http://cantus.uwaterloo.ca/chant/149254> .
#
#     <https://w3id.org/musow/1635268063-595771/> rdfs:label "Cantus Manuscript Database" ;
#         prov:generatedAtTime "2021-10-26T17:07:44.406716"^^xsd:dateTime ;
#         prov:wasAttributedTo musow:marilena-dot-daquino2-at-unibo-dot-it ;
#         musow:publicationStage "published" .
#
#     <http://purl.org/ontology/mo/Score> rdfs:label "Score" .
#
#     musow:1635268063-601466 rdfs:label "Cantus Melody search" .
#
#     musow:1635268063-602125 rdfs:label "SIMSSA OMR" .
#
#     musow:6b6f0f012cc638cd7a6c26f5fef91d21 rdfs:label "Single Interface for Music Score Searching and Analysis project" .
#
#     musow:marilena-dot-daquino2-at-unibo-dot-it rdfs:label "marilena.daquino2@unibo.it" .
#
#     <https://w3id.org/musow/vocab/browse-interface> rdfs:label "Provides interfaces for browsing contents" .
#
#     <https://w3id.org/musow/vocab/cc-by-nc-sa> rdfs:label "CC-BY-NC-SA" .
#
#     <https://w3id.org/musow/vocab/data-visualization> rdfs:label "data visualization" .
#
#     <https://w3id.org/musow/vocab/dataset> rdfs:label "Dataset" .
#
#     <https://w3id.org/musow/vocab/descriptive-metadata> rdfs:label "Descriptive Metadata" .
#
#     <https://w3id.org/musow/vocab/genre> rdfs:label "Genre" .
#
#     <https://w3id.org/musow/vocab/geographical> rdfs:label "Geographical" .
#
#     <https://w3id.org/musow/vocab/human-consumption> rdfs:label "Provides user-friendly interfaces" .
#
#     <https://w3id.org/musow/vocab/interoperable> rdfs:label "Shares data in open data formats" .
#
#     <https://w3id.org/musow/vocab/jpg> rdfs:label "jpg" .
#
#     <https://w3id.org/musow/vocab/lt-1000> rdfs:label "<1000" .
#
#     <https://w3id.org/musow/vocab/lyrics> rdfs:label "Lyrics" .
#
#     <https://w3id.org/musow/vocab/machine-readable> rdfs:label "Serves machine-readable music data" .
#
#     <https://w3id.org/musow/vocab/melody> rdfs:label "Melody" .
#
#     <https://w3id.org/musow/vocab/research> rdfs:label "Research" .
#
#     <https://w3id.org/musow/vocab/researchers> rdfs:label "researchers" .
#
#     <https://w3id.org/musow/vocab/search-interface> rdfs:label "Provides user-friendly search interfaces" .
#
#     <https://w3id.org/musow/vocab/structure> rdfs:label "Music structure" .
#
#     <https://w3id.org/musow/vocab/symbolic> rdfs:label "Symbolic" .
#
#     <https://w3id.org/musow/vocab/temporal> rdfs:label "Temporal" .
# }
#
# <https://w3id.org/musow/1635268063-58305/> {
#     <https://w3id.org/musow/1635268063-58305/> rdfs:label "Archive of Seventeenth-Century Italian Madrigals and Arias (ASCIMA)" ;
#         prov:generatedAtTime "2021-10-26T17:07:43.838853"^^xsd:dateTime ;
#         prov:wasAttributedTo musow:marilena-dot-daquino2-at-unibo-dot-it ;
#         musow:publicationStage "published" .
#
#     <http://purl.org/ontology/mo/Score> rdfs:label "Score" .
#
#     musow:1635268063-58305 a schema:CreativeWork ;
#         rdfs:label "Archive of Seventeenth-Century Italian Madrigals and Arias (ASCIMA)" ;
#         ns1:sameAs <http://data.open.ac.uk/musow/ad45805300d2b2f1ce6d38eddba228ae> ;
#         schema:about <https://w3id.org/musow/vocab/artist>,
#             <https://w3id.org/musow/vocab/genre>,
#             <https://w3id.org/musow/vocab/geographical>,
#             <https://w3id.org/musow/vocab/temporal> ;
#         schema:additionalType <https://w3id.org/musow/vocab/digital-edition> ;
#         schema:audience <https://w3id.org/musow/vocab/researchers> ;
#         schema:category <https://w3id.org/musow/vocab/symbolic> ;
#         schema:collectionSize <https://w3id.org/musow/vocab/lt-1000> ;
#         schema:contentSize <https://w3id.org/musow/vocab/gb> ;
#         schema:creator musow:1635268063-58305 ;
#         schema:description "Critical editions of 17th century Italian madrigals and arias, with introductions in Italian, German and English, and translations of the texts into English and German. As of May 2013, composers represented include Claudio Monteverdi, Giovanni Rovetta, and Giovanni Valentini." ;
#         schema:educationalUse <https://w3id.org/musow/vocab/research> ;
#         schema:encodingFormat <https://w3id.org/musow/vocab/audio>,
#             <https://w3id.org/musow/vocab/mov>,
#             <https://w3id.org/musow/vocab/pdf> ;
#         schema:featureList <https://w3id.org/musow/vocab/browse-interface>,
#             <https://w3id.org/musow/vocab/data-dump>,
#             <https://w3id.org/musow/vocab/human-consumption>,
#             <https://w3id.org/musow/vocab/playable> ;
#         schema:keywords <https://w3id.org/musow/vocab/descriptive-metadata> ;
#         schema:license <https://w3id.org/musow/vocab/open-access> ;
#         schema:mainEntity <http://purl.org/ontology/mo/Score> ;
#         schema:mainEntityOfPage <http://www.birmingham.ac.uk/schools/lcahm/departments/music/research/ascima/index.aspx> ;
#         schema:name "Archive of Seventeenth-Century Italian Madrigals and Arias (ASCIMA)" ;
#         schema:specialty <https://w3id.org/musow/vocab/music-history> ;
#         schema:workExample <http://epapers.bham.ac.uk/1679/> .
#
#     musow:marilena-dot-daquino2-at-unibo-dot-it rdfs:label "marilena.daquino2@unibo.it" .
#
#     <https://w3id.org/musow/vocab/artist> rdfs:label "Composer" .
#
#     <https://w3id.org/musow/vocab/audio> rdfs:label "audio" .
#
#     <https://w3id.org/musow/vocab/browse-interface> rdfs:label "Provides interfaces for browsing contents" .
#
#     <https://w3id.org/musow/vocab/data-dump> rdfs:label "Offers data export or dump" .
#
#     <https://w3id.org/musow/vocab/descriptive-metadata> rdfs:label "Descriptive Metadata" .
#
#     <https://w3id.org/musow/vocab/digital-edition> rdfs:label "Digital edition" .
#
#     <https://w3id.org/musow/vocab/gb> rdfs:label "~Gb" .
#
#     <https://w3id.org/musow/vocab/genre> rdfs:label "Genre" .
#
#     <https://w3id.org/musow/vocab/geographical> rdfs:label "Geographical" .
#
#     <https://w3id.org/musow/vocab/human-consumption> rdfs:label "Provides user-friendly interfaces" .
#
#     <https://w3id.org/musow/vocab/lt-1000> rdfs:label "<1000" .
#
#     <https://w3id.org/musow/vocab/mov> rdfs:label "mov" .
#
# ...
#         schema:additionalType <https://w3id.org/musow/vocab/digital-library> ;
#         schema:audience <https://w3id.org/musow/vocab/researchers> ;
#         schema:category <https://w3id.org/musow/vocab/metadata> ;
#         schema:creator musow:853fc2f9cff6232df0c1ceb1534a8c02 ;
#         schema:description "Digital library of music books, recordings, scores, descriptive metadata. It allows to search for voices and instruments" ;
#         schema:educationalUse <https://w3id.org/musow/vocab/research> ;
#         schema:encodingFormat <https://w3id.org/musow/vocab/audio>,
#             <https://w3id.org/musow/vocab/video> ;
#         schema:featureList <https://w3id.org/musow/vocab/api>,
#             <https://w3id.org/musow/vocab/browse-interface>,
#             <https://w3id.org/musow/vocab/human-consumption>,
#             <https://w3id.org/musow/vocab/interoperable>,
#             <https://w3id.org/musow/vocab/machine-readable>,
#             <https://w3id.org/musow/vocab/playable>,
#             <https://w3id.org/musow/vocab/search-interface> ;
#         schema:keywords <https://w3id.org/musow/vocab/descriptive-metadata>,
#             <https://w3id.org/musow/vocab/structure>,
#             <https://w3id.org/musow/vocab/timbre> ;
#         schema:license <https://w3id.org/musow/vocab/open-access> ;
#         schema:mainEntity <http://purl.org/ontology/mo/MusicalWork>,
#             <https://w3id.org/musow/vocab/musical-resource> ;
#         schema:mainEntityOfPage <http://www.library.unt.edu/research> ;
#         schema:name "UNT Music Catalog" ;
#         schema:specialty <https://w3id.org/musow/vocab/metadata-aggregation> ;
#         schema:workExample <http://iii.library.unt.edu/record=b2566319~S7> .
#
#     <https://w3id.org/musow/1635268063-597189/> rdfs:label "UNT Music Catalog" ;
#         prov:generatedAtTime "2021-10-26T17:07:44.492953"^^xsd:dateTime ;
#         prov:wasAttributedTo musow:marilena-dot-daquino2-at-unibo-dot-it ;
#         musow:publicationStage "published" .
#
#     <http://purl.org/ontology/mo/MusicalWork> rdfs:label "Musical Work" .
#
#     musow:853fc2f9cff6232df0c1ceb1534a8c02 rdfs:label "University Libraries of Texas" .
#
#     musow:marilena-dot-daquino2-at-unibo-dot-it rdfs:label "marilena.daquino2@unibo.it" .
#
#     <https://w3id.org/musow/vocab/api> rdfs:label "Offers a Web API" .
#
#     <https://w3id.org/musow/vocab/audio> rdfs:label "audio" .
#
#     <https://w3id.org/musow/vocab/browse-interface> rdfs:label "Provides interfaces for browsing contents" .
#
#     <https://w3id.org/musow/vocab/descriptive-metadata> rdfs:label "Descriptive Metadata" .
#
#     <https://w3id.org/musow/vocab/digital-library> rdfs:label "Digital Library" .
#
#     <https://w3id.org/musow/vocab/genre> rdfs:label "Genre" .
#
#     <https://w3id.org/musow/vocab/geographical> rdfs:label "Geographical" .
#
#     <https://w3id.org/musow/vocab/human-consumption> rdfs:label "Provides user-friendly interfaces" .
#
#     <https://w3id.org/musow/vocab/interoperable> rdfs:label "Shares data in open data formats" .
#
#     <https://w3id.org/musow/vocab/machine-readable> rdfs:label "Serves machine-readable music data" .
#
#     <https://w3id.org/musow/vocab/metadata> rdfs:label "Metadata" .
#
#     <https://w3id.org/musow/vocab/metadata-aggregation> rdfs:label "metadata aggregation" .
#
#     <https://w3id.org/musow/vocab/musical-resource> rdfs:label "Musical resource" .
#
#     <https://w3id.org/musow/vocab/open-access> rdfs:label "Open Access" .
#
#     <https://w3id.org/musow/vocab/playable> rdfs:label "Offers playable music records" .
#
#     <https://w3id.org/musow/vocab/research> rdfs:label "Research" .
#
#     <https://w3id.org/musow/vocab/researchers> rdfs:label "researchers" .
#
#     <https://w3id.org/musow/vocab/search-interface> rdfs:label "Provides user-friendly search interfaces" .
#
#     <https://w3id.org/musow/vocab/structure> rdfs:label "Music structure" .
#
#     <https://w3id.org/musow/vocab/timbre> rdfs:label "Timbre" .
#
#     <https://w3id.org/musow/vocab/video> rdfs:label "video" .
# }
#
# <https://w3id.org/musow/1635268063-599139/> {
#     <https://w3id.org/musow/1635268063-599139/> rdfs:label "IMSLP Petrucci Music Library" ;
#         prov:generatedAtTime "2021-10-26T17:07:44.669645"^^xsd:dateTime ;
#         prov:wasAttributedTo musow:marilena-dot-daquino2-at-unibo-dot-it ;
#         musow:publicationStage "published" .
#
#     <http://purl.org/ontology/mo/Score> rdfs:label "Score" .
#
#     musow:1635268063-597556 rdfs:label "MusicXML" .
#
#     musow:1635268063-599139 a schema:CreativeWork ;
#         rdfs:label "IMSLP Petrucci Music Library" ;
#         ns1:sameAs <http://data.open.ac.uk/musow/2bdebe9cfcdeff29c5809ab0241873b5> ;
#         schema:additionalType <https://w3id.org/musow/vocab/repository> ;
#         schema:audience <https://w3id.org/musow/vocab/performers>,
#             <https://w3id.org/musow/vocab/scholars> ;
#         schema:category <https://w3id.org/musow/vocab/symbolic> ;
#         schema:collectionSize <https://w3id.org/musow/vocab/lt-1m> ;
#         schema:creator musow:1635268063-599139 ;
#         schema:description "IMSLP, the International Music Score Library Project, has one of the largest collection of online public domain scores in the Petrucci Music Library, with over 110,000 works (almost 400,000 scores). IMSLP provides files in PDF format, but an increasing number of these PDF files include MusicXML attachments." ;
#         schema:educationalUse <https://w3id.org/musow/vocab/learning> ;
#         schema:encodingFormat <https://w3id.org/musow/vocab/finale>,
#             <https://w3id.org/musow/vocab/musicxml>,
#             <https://w3id.org/musow/vocab/pdf> ;
#         schema:featureList <https://w3id.org/musow/vocab/browse-interface>,
#             <https://w3id.org/musow/vocab/data-dump>,
#             <https://w3id.org/musow/vocab/human-consumption>,
#             <https://w3id.org/musow/vocab/interoperable>,
#             <https://w3id.org/musow/vocab/machine-readable>,
#             <https://w3id.org/musow/vocab/playable>,
#             <https://w3id.org/musow/vocab/search-interface> ;
#         schema:isBasedOn musow:1635268063-597556 ;
#         schema:keywords <https://w3id.org/musow/vocab/descriptive-metadata>,
#             <https://w3id.org/musow/vocab/harmony>,
#             <https://w3id.org/musow/vocab/lyrics>,
#             <https://w3id.org/musow/vocab/melody>,
#             <https://w3id.org/musow/vocab/rhythm> ;
#         schema:license <https://w3id.org/musow/vocab/cc0> ;
#         schema:mainEntity <http://purl.org/ontology/mo/Score> ;
#         schema:mainEntityOfPage <http://imslp.org/wiki/Main_Page> ;
#         schema:name "IMSLP Petrucci Music Library" ;
#         schema:specialty <https://w3id.org/musow/vocab/>,
#             <https://w3id.org/musow/vocab/music-learning> ;
#         schema:workExample <http://imslp.org/wiki/Carol_of_the_Drum_(Rondeau%2C_Michel)> .
#
#     musow:marilena-dot-daquino2-at-unibo-dot-it rdfs:label "marilena.daquino2@unibo.it" .
#
#     <https://w3id.org/musow/vocab/> rdfs:label "" .
#
#     <https://w3id.org/musow/vocab/browse-interface> rdfs:label "Provides interfaces for browsing contents" .
#
#     <https://w3id.org/musow/vocab/cc0> rdfs:label "CC0" .
#
#     <https://w3id.org/musow/vocab/data-dump> rdfs:label "Offers data export or dump" .
#
#     <https://w3id.org/musow/vocab/descriptive-metadata> rdfs:label "Descriptive Metadata" .
#
#     <https://w3id.org/musow/vocab/finale> rdfs:label "finale" .
#
#     <https://w3id.org/musow/vocab/harmony> rdfs:label "Harmony" .
#
#     <https://w3id.org/musow/vocab/human-consumption> rdfs:label "Provides user-friendly interfaces" .
#
#     <https://w3id.org/musow/vocab/interoperable> rdfs:label "Shares data in open data formats" .
#
#     <https://w3id.org/musow/vocab/learning> rdfs:label "Learning" .
#
#     <https://w3id.org/musow/vocab/lt-1m> rdfs:label "<1M" .
#
#     <https://w3id.org/musow/vocab/lyrics> rdfs:label "Lyrics" .
#
#     <https://w3id.org/musow/vocab/machine-readable> rdfs:label "Serves machine-readable music data" .
#
#     <https://w3id.org/musow/vocab/melody> rdfs:label "Melody" .
#
#     <https://w3id.org/musow/vocab/music-learning> rdfs:label "music learning" .
#
#     <https://w3id.org/musow/vocab/musicxml> rdfs:label "musicxml" .
#
#     <https://w3id.org/musow/vocab/pdf> rdfs:label "pdf" .
#
#     <https://w3id.org/musow/vocab/performers> rdfs:label "performers" .
#
#     <https://w3id.org/musow/vocab/playable> rdfs:label "Offers playable music records" .
#
#     <https://w3id.org/musow/vocab/repository> rdfs:label "Repository" .
#
#     <https://w3id.org/musow/vocab/rhythm> rdfs:label "Rhythm" .
#
#     <https://w3id.org/musow/vocab/scholars> rdfs:label "scholars" .
#
#     <https://w3id.org/musow/vocab/search-interface> rdfs:label "Provides user-friendly search interfaces" .
#
#     <https://w3id.org/musow/vocab/symbolic> rdfs:label "Symbolic" .
# }
#
# <https://w3id.org/musow/1635268063-588784/> {
#     <https://w3id.org/musow/1635268063-588784/> rdfs:label "IN Harmony: Sheet Music from Indiana" ;
#         prov:generatedAtTime "2021-10-26T17:07:44.111494"^^xsd:dateTime ;
#         prov:wasAttributedTo musow:marilena-dot-daquino2-at-unibo-dot-it ;
#         musow:publicationStage "published" .
#
#     <http://purl.org/ontology/mo/Score> rdfs:label "Score" .
#
#     musow:1635268063-588784 a schema:CreativeWork ;
#         rdfs:label "IN Harmony: Sheet Music from Indiana" ;
#         ns1:sameAs <http://data.open.ac.uk/musow/238ae03523db3c0676c973ff937479e5> ;
#         schema:about <https://w3id.org/musow/vocab/geographical> ;
#         schema:additionalType <https://w3id.org/musow/vocab/repository> ;
#         schema:audience <https://w3id.org/musow/vocab/researchers> ;
#         schema:category <https://w3id.org/musow/vocab/symbolic> ;
#         schema:collectionSize <https://w3id.org/musow/vocab/lt-1m> ;
#         schema:creator musow:1635268063-588784 ;
#         schema:description "Over 10,000 digitized pieces of sheet music by Indiana composers, arrangers, lyricists or publishers, as well as music about the state.  " ;
#         schema:educationalUse <https://w3id.org/musow/vocab/research> ;
#         schema:encodingFormat <https://w3id.org/musow/vocab/mods/xml>,
#             <https://w3id.org/musow/vocab/pdf> ;
#         schema:featureList <https://w3id.org/musow/vocab/api>,
#             <https://w3id.org/musow/vocab/browse-interface>,
#             <https://w3id.org/musow/vocab/data-dump>,
#             <https://w3id.org/musow/vocab/human-consumption>,
#             <https://w3id.org/musow/vocab/interoperable> ;
#         schema:keywords <https://w3id.org/musow/vocab/descriptive-metadata> ;
#         schema:license <https://w3id.org/musow/vocab/copyright> ;
#         schema:mainEntity <http://purl.org/ontology/mo/Score> ;
#         schema:mainEntityOfPage <http://webapp1.dlib.indiana.edu/inharmony/welcome.do> ;
#         schema:name "IN Harmony: Sheet Music from Indiana" ;
#         schema:specialty <https://w3id.org/musow/vocab/music-history>,
#             <https://w3id.org/musow/vocab/musicology> ;
#         schema:workExample <http://webapp1.dlib.indiana.edu/inharmony/detail.do?action=detail&fullItemID=/lilly/starr/LL-SSM-2-135-0025&queryNumber=3> .
#
#     musow:marilena-dot-daquino2-at-unibo-dot-it rdfs:label "marilena.daquino2@unibo.it" .
#
#     <https://w3id.org/musow/vocab/api> rdfs:label "Offers a Web API" .
#
#     <https://w3id.org/musow/vocab/browse-interface> rdfs:label "Provides interfaces for browsing contents" .
#
#     <https://w3id.org/musow/vocab/copyright> rdfs:label "Copyright" .
#
#     <https://w3id.org/musow/vocab/data-dump> rdfs:label "Offers data export or dump" .
#
#     <https://w3id.org/musow/vocab/descriptive-metadata> rdfs:label "Descriptive Metadata" .
#
#     <https://w3id.org/musow/vocab/geographical> rdfs:label "Geographical" .
#
#     <https://w3id.org/musow/vocab/human-consumption> rdfs:label "Provides user-friendly interfaces" .
#
#     <https://w3id.org/musow/vocab/interoperable> rdfs:label "Shares data in open data formats" .
#
#     <https://w3id.org/musow/vocab/lt-1m> rdfs:label "<1M" .
#
#     <https://w3id.org/musow/vocab/mods/xml> rdfs:label "mods/xml" .
#
#     <https://w3id.org/musow/vocab/music-history> rdfs:label "music history" .
#
#     <https://w3id.org/musow/vocab/musicology> rdfs:label "musicology" .
#
#     <https://w3id.org/musow/vocab/pdf> rdfs:label "pdf" .
#
#     <https://w3id.org/musow/vocab/repository> rdfs:label "Repository" .
#
#     <https://w3id.org/musow/vocab/research> rdfs:label "Research" .
#
#     <https://w3id.org/musow/vocab/researchers> rdfs:label "researchers" .
#
#     <https://w3id.org/musow/vocab/symbolic> rdfs:label "Symbolic" .
# }
#
# <https://w3id.org/musow/1635268063-594427/> {
#     <https://w3id.org/musow/1635268063-594427/> rdfs:label "MusOpen" ;
#         prov:generatedAtTime "2021-10-26T17:07:44.347248"^^xsd:dateTime ;
#         prov:wasAttributedTo musow:marilena-dot-daquino2-at-unibo-dot-it ;
#         musow:publicationStage "published" .
#
#     <http://purl.org/ontology/mo/Score> rdfs:label "Score" .
#
#     musow:1635268063-594427 a schema:CreativeWork ;
#         rdfs:label "MusOpen" ;
#         ns1:sameAs <http://data.open.ac.uk/musow/8a0152fe0d162b410de71d7401c11881> ;
#         schema:additionalType <https://w3id.org/musow/vocab/repository> ;
#         schema:audience <https://w3id.org/musow/vocab/performers>,
#             <https://w3id.org/musow/vocab/scholars> ;
#         schema:category <https://w3id.org/musow/vocab/symbolic> ;
#         schema:collectionSize <https://w3id.org/musow/vocab/lt-1m> ;
#         schema:creator musow:1635268063-594427 ;
#         schema:description "Musopen is a 501(c)(3) non-profit focused on increasing access to music by creating free resources and educational materials. We provide recordings, sheet music, and textbooks to the public for free, without copyright restrictions. Put simply, our mission is to set music free." ;
#         schema:educationalUse <https://w3id.org/musow/vocab/learning> ;
#         schema:encodingFormat <https://w3id.org/musow/vocab/audio>,
#             <https://w3id.org/musow/vocab/pdf> ;
#         schema:featureList <https://w3id.org/musow/vocab/browse-interface>,
#             <https://w3id.org/musow/vocab/data-dump>,
#             <https://w3id.org/musow/vocab/human-consumption>,
#             <https://w3id.org/musow/vocab/playable> ;
#         schema:keywords <https://w3id.org/musow/vocab/descriptive-metadata> ;
#         schema:license <https://w3id.org/musow/vocab/cc0> ;
#         schema:mainEntity <http://purl.org/ontology/mo/Score> ;
#         schema:mainEntityOfPage <https://musopen.org/sheetmusic/> ;
#         schema:name "MusOpen" ;
#         schema:specialty <https://w3id.org/musow/vocab/music-learning>,
#             <https://w3id.org/musow/vocab/performance> ;
#         schema:workExample <https://musopen.org/sheetmusic/25583/carlo-alboni/genl-franklin-pierces-grand-march/> .
#
#     musow:marilena-dot-daquino2-at-unibo-dot-it rdfs:label "marilena.daquino2@unibo.it" .
#
#     <https://w3id.org/musow/vocab/audio> rdfs:label "audio" .
#
#     <https://w3id.org/musow/vocab/browse-interface> rdfs:label "Provides interfaces for browsing contents" .
#
#     <https://w3id.org/musow/vocab/cc0> rdfs:label "CC0" .
#
#     <https://w3id.org/musow/vocab/data-dump> rdfs:label "Offers data export or dump" .
#
#     <https://w3id.org/musow/vocab/descriptive-metadata> rdfs:label "Descriptive Metadata" .
#
#     <https://w3id.org/musow/vocab/human-consumption> rdfs:label "Provides user-friendly interfaces" .
#
#     <https://w3id.org/musow/vocab/learning> rdfs:label "Learning" .
#
#     <https://w3id.org/musow/vocab/lt-1m> rdfs:label "<1M" .
#
#     <https://w3id.org/musow/vocab/music-learning> rdfs:label "music learning" .
#
#     <https://w3id.org/musow/vocab/pdf> rdfs:label "pdf" .
#
#     <https://w3id.org/musow/vocab/performance> rdfs:label "performance" .
#
#     <https://w3id.org/musow/vocab/performers> rdfs:label "performers" .
#
#     <https://w3id.org/musow/vocab/playable> rdfs:label "Offers playable music records" .
#
#     <https://w3id.org/musow/vocab/repository> rdfs:label "Repository" .
#
#     <https://w3id.org/musow/vocab/scholars> rdfs:label "scholars" .
#
#     <https://w3id.org/musow/vocab/symbolic> rdfs:label "Symbolic" .
# }

# %% [markdown]
# ## JSON schema for the web form

# %%
# prepare JSON form
field_title = column_to_json("res_title", "True", "Literal", "The title of the resource",
                   "title", "Textbox", schema+"name", "e.g. Listening Experience Database",
                   "True", "False", "False",
                   "col-md-11", "off", field_values=None)

field_homepage = column_to_json("res_homepage", "False", "Literal", "The URL of the homepage of the resource",
                   "homepage", "Textbox", schema+"mainEntityOfPage", "e.g. https://led.kmi.open.ac.uk/",
                   "False", "False", "False",
                   "col-md-11", "off", field_values=None)

field_description = column_to_json("res_description", "False", "Literal", "A short description of the resource",
                   "description", "Textbox", schema+"description", "e.g. An open and freely searchable database ...",
                   "False", "False", "False",
                   "col-md-11", "off", field_values=None)

field_creator = column_to_json("res_creator", "False", "URI", "The persons, organisations, or project responsible for the resource",
                   "creator or project", "Textbox", schema+"creator", "e.g. The Open University",
                   "True", "True", "False",
                   "col-md-11", "off", field_values=None)

field_type = column_to_json("res_type", "False", "URI", "The type of resource",
                   "type", "Dropdown", schema+"additionalType", "",
                   "True", "False", "False",
                   "col-md-11", "off", field_values={v: k for k, v in res_types.items()})

field_purpose = column_to_json("res_purpose", "False", "URI", "The purpose of the resource, e.g. a research project, a learning resource",
                   "purpose", "Dropdown", schema+"educationalUse", "",
                   "False", "False", "False",
                   "col-md-11", "off", field_values={v: k for k, v in res_educational.items()})

field_audience = column_to_json("res_audience", "False", "URI", "The target audience of the resource",
                   "audience", "Checkbox", schema+"audience", "",
                   "True", "False", "False",
                   "col-md-11", "off", field_values={v: k for k, v in res_audiences.items()})

field_task = column_to_json("res_task", "False", "URI", "What task or research discipline is the resource relevant to?",
                   "task or research field", "Checkbox", schema+"specialty", "",
                   "True", "False", "False",
                   "col-md-11", "off", field_values={v: k for k, v in res_tasks.items()})

field_features = column_to_json("res_features", "False", "URI", "The technical features that the online resource offers",
                   "technical features", "Checkbox", schema+"featureList", "",
                   "False", "False", "False",
                   "col-md-11", "off", field_values={v: k for k, v in res_app_features.items()})

field_based_on = column_to_json("res_reused", "False", "URI", "A tool, a dataset, a vocabulary, or any other component that is reused by the resource",
                   "reused resources", "Textbox", schema+"isBasedOn", "Gutenberg project",
                   "False", "True", "False",
                   "col-md-11", "off", field_values=None)

field_example = column_to_json("res_example", "False", "Literal", "If the resource collects music-related resources, the URL of an exemplar resource",
                   "example resource", "Textbox", schema+"workExample", "e.g. https://led.kmi.open.ac.uk/entity/lexp/1628588049214",
                   "False", "False", "False",
                   "col-md-11", "off", field_values=None)

res_subjects = {**res_mo_types , **res_subject_types}
field_subject = column_to_json("res_subject", "False", "URI", "If the resource collects music-related resources, what are these?",
                   "type of collected resources", "Checkbox", schema+"mainEntity", "",
                   "True", "False", "False",
                   "col-md-11", "off", field_values={v: k for k, v in res_subjects.items()})

field_scope = column_to_json("res_scope", "False", "URI", "If the resource collects music-related resources, what is the scope of the collection?",
                   "scope of the collection", "Checkbox", schema+"about", "",
                   "False", "False", "False",
                   "col-md-11", "off", field_values={v: k for k, v in res_scope.items()}) 

field_temporal = column_to_json("res_temporal", "False", "URI", "Which historical period does the resource address?",
                   "temporal scope of data", "Textbox", schema+"temporalCoverage", "e.g. XX century",
                   "False", "True", "False",
                   "col-md-11", "off", field_values=None)

field_geo = column_to_json("res_geo", "False", "URI", "Which geographical places does the resource address?",
                   "geographical scope of data", "Textbox", schema+"spatialCoverage", "e.g. Italy",
                   "False", "True", "False",
                   "col-md-11", "off", field_values=None)

field_genre = column_to_json("res_genre", "False", "URI", "Which music genres does the resource address?",
                   "music genre in scope", "Textbox", schema+"genre", "e.g. Jazz",
                   "False", "True", "False",
                   "col-md-11", "off", field_values=None)

field_artist = column_to_json("res_artist", "False", "URI", "Which composers, performers, or interesting people does the resource address?",
                   "people in scope", "Textbox", schema+"character", "e.g. Louis Armstrong",
                   "False", "True", "False",
                   "col-md-11", "off", field_values=None)

field_category = column_to_json("res_category", "False", "URI", "If the resource collects music-related resources, what kind of data are provided for the resources?",
                   "category of data collected", "Checkbox", schema+"category", "",
                   "True", "False", "False",
                   "col-md-11", "off", field_values={v: k for k, v in res_categories.items()})

field_music_feature = column_to_json("res_music_feature", "False", "URI", "If the resource collects symbolic data of music resources, what type of music feature is provided as structured data?",
                   "music data features", "Checkbox", schema+"keywords", "",
                   "True", "False", "False",
                   "col-md-11", "off", field_values={v: k for k, v in res_data_features.items()})

field_collection = column_to_json("res_collectionsize", "False", "URI", "If the resource collects music-related resources, can you estimate the size of the collection?",
                   "collection size", "Dropdown", schema+"collectionSize", "",
                   "True", "False", "False",
                   "col-md-11", "off", field_values={v: k for k, v in res_collection_size.items()})




field_format = column_to_json("res_format", "False", "URI", "If the resource collects music-related resources, in what data format are these served?",
                   "data formats", "Checkbox", schema+"encodingFormat", "",
                   "False", "False", "False",
                   "col-md-11", "off", field_values={v: k for k, v in res_formats.items()})

field_license = column_to_json("res_license", "False", "URI", "If the resource collects music-related resources, which licence is specified for their reuse?",
                   "data license", "Dropdown", schema+"license", "",
                   "True", "False", "False",
                   "col-md-11", "off", field_values={v: k for k, v in res_licenses.items()})

field_content = column_to_json("res_datasize", "False", "URI", "If the resource serves data, can you estimate of the size of data?",
                   "data size", "Dropdown", schema+"contentSize", "",
                   "True", "False", "False",
                   "col-md-11", "off", field_values={v: k for k, v in res_datasize.items()})

field_distribution = column_to_json("res_distribution", "False", "Literal", "If the resource serves data, the URL of the latest data distribution",
                   "data download URL", "Textbox", schema+"downloadUrl", "e.g. https://led.kmi.open.ac.uk/rdf/export/led-SNAPSHOT.nt.bz2",
                   "False", "False", "False",
                   "col-md-11", "off", field_values=None)

field_sparql = column_to_json("res_sparql", "False", "Literal", "If the resource serves data, the URL of the SPARQL endpoint of the resource, if applicable",
                   "SPARQL endpoint", "Textbox", "http://rdfs.org/ns/void#sparqlEndpoint", "e.g. https://data.open.ac.uk/query",
                   "False", "False", "False",
                   "col-md-11", "off", field_values=None)

field_api = column_to_json("res_api", "False", "Literal", "If the resource serves data, the URL of the API",
                   "web API", "Textbox", schema+"serviceUrl", "e.g. http://example.org/api/",
                   "False", "False", "False",
                   "col-md-11", "off", field_values=None)


musow_form = [field_title, 
              field_homepage, 
              field_description,
              field_creator,
              field_type,
              field_purpose,
              field_audience,
              field_task,
              field_features,
              field_based_on,
              field_example,
              field_subject,
              field_scope,
              field_temporal, 
              field_geo, 
              field_genre, 
              field_artist,
              field_category,
              field_music_feature,
              field_collection,
              field_format,
              field_license,
              field_content,
              field_distribution, 
              field_sparql,
              field_api]

# CHANGE sort the fields
musow_form
# Out:
# [{'browse': 'True',
#   'cache_autocomplete': 'off',
#   'class': 'col-md-11',
#   'disabled': 'False',
#   'disambiguate': 'True',
#   'id': 'res_title',
#   'label': 'title',
#   'placeholder': 'e.g. Listening Experience Database',
#   'prepend': 'The title of the resource',
#   'property': 'https://schema.org/name',
#   'searchWikidata': 'False',
#   'type': 'Textbox',
#   'value': 'Literal'},
#  {'browse': 'False',
#   'cache_autocomplete': 'off',
#   'class': 'col-md-11',
#   'disabled': 'False',
#   'disambiguate': 'False',
#   'id': 'res_homepage',
#   'label': 'homepage',
#   'placeholder': 'e.g. https://led.kmi.open.ac.uk/',
#   'prepend': 'The URL of the homepage of the resource',
#   'property': 'https://schema.org/mainEntityOfPage',
#   'searchWikidata': 'False',
#   'type': 'Textbox',
#   'value': 'Literal'},
#  {'browse': 'False',
#   'cache_autocomplete': 'off',
#   'class': 'col-md-11',
#   'disabled': 'False',
#   'disambiguate': 'False',
#   'id': 'res_description',
#   'label': 'description',
#   'placeholder': 'e.g. An open and freely searchable database ...',
#   'prepend': 'A short description of the resource',
#   'property': 'https://schema.org/description',
#   'searchWikidata': 'False',
#   'type': 'Textbox',
#   'value': 'Literal'},
#  {'browse': 'True',
#   'cache_autocomplete': 'off',
#   'class': 'col-md-11',
#   'disabled': 'False',
#   'disambiguate': 'False',
#   'id': 'res_creator',
#   'label': 'creator or project',
#   'placeholder': 'e.g. The Open University',
#   'prepend': 'The persons, organisations, or project responsible for the resource',
#   'property': 'https://schema.org/creator',
#   'searchWikidata': 'True',
#   'type': 'Textbox',
#   'value': 'URI'},
#  {'browse': 'True',
#   'cache_autocomplete': 'off',
#   'class': 'col-md-11',
#   'disabled': 'False',
#   'disambiguate': 'False',
#   'id': 'res_type',
#   'label': 'type',
#   'placeholder': '',
#   'prepend': 'The type of resource',
#   'property': 'https://schema.org/additionalType',
#   'searchWikidata': 'False',
#   'type': 'Dropdown',
#   'value': 'URI',
#   'values': {'https://w3id.org/musow/vocab/catalogue': 'Catalogue',
#    'https://w3id.org/musow/vocab/dataset': 'Dataset',
#    'https://w3id.org/musow/vocab/digital-edition': 'Digital edition',
#    'https://w3id.org/musow/vocab/digital-library': 'Digital Library',
#    'https://w3id.org/musow/vocab/format': 'Format',
#    'https://w3id.org/musow/vocab/ontology': 'Ontology',
#    'https://w3id.org/musow/vocab/project': 'Project',
#    'https://w3id.org/musow/vocab/repository': 'Repository',
#    'https://w3id.org/musow/vocab/schema': 'Schema',
#    'https://w3id.org/musow/vocab/service': 'Service',
#    'https://w3id.org/musow/vocab/software': 'Software'}},
#  {'browse': 'False',
#   'cache_autocomplete': 'off',
#   'class': 'col-md-11',
#   'disabled': 'False',
#   'disambiguate': 'False',
#   'id': 'res_purpose',
#   'label': 'purpose',
#   'placeholder': '',
#   'prepend': 'The purpose of the resource, e.g. a research project, a learning resource',
#   'property': 'https://schema.org/educationalUse',
#   'searchWikidata': 'False',
#   'type': 'Dropdown',
#   'value': 'URI',
#   'values': {'https://w3id.org/musow/vocab/learning': 'Learning',
#    'https://w3id.org/musow/vocab/research': 'Research'}},
#  {'browse': 'True',
#   'cache_autocomplete': 'off',
#   'class': 'col-md-11',
#   'disabled': 'False',
#   'disambiguate': 'False',
#   'id': 'res_audience',
#   'label': 'audience',
#   'placeholder': '',
#   'prepend': 'The target audience of the resource',
#   'property': 'https://schema.org/audience',
#   'searchWikidata': 'False',
#   'type': 'Checkbox',
#   'value': 'URI',
#   'values': {'https://w3id.org/musow/vocab/amateurs': 'amateurs',
#    'https://w3id.org/musow/vocab/customers': 'customers',
#    'https://w3id.org/musow/vocab/developers': 'developers',
#    'https://w3id.org/musow/vocab/listeners': 'listeners',
#    'https://w3id.org/musow/vocab/performers': 'performers',
#    'https://w3id.org/musow/vocab/record-companies': 'record companies',
#    'https://w3id.org/musow/vocab/researchers': 'researchers',
#    'https://w3id.org/musow/vocab/scholars': 'scholars'}},
#  {'browse': 'True',
#   'cache_autocomplete': 'off',
#   'class': 'col-md-11',
#   'disabled': 'False',
#   'disambiguate': 'False',
#   'id': 'res_task',
#   'label': 'task or research field',
#   'placeholder': '',
#   'prepend': 'What task or research discipline is the resource relevant to?',
#   'property': 'https://schema.org/specialty',
#   'searchWikidata': 'False',
#   'type': 'Checkbox',
#   'value': 'URI',
#   'values': {'https://w3id.org/musow/vocab/architecture': 'architecture',
#    'https://w3id.org/musow/vocab/archival-studies': 'archival studies',
#    'https://w3id.org/musow/vocab/audio-annotation': 'audio annotation',
#    'https://w3id.org/musow/vocab/audio-beat-tracking': 'audio beat tracking',
#    'https://w3id.org/musow/vocab/audio-chord-estimation': 'audio chord estimation',
#    'https://w3id.org/musow/vocab/audio-classification': 'audio classification',
#    'https://w3id.org/musow/vocab/audio-cover-song-identification': 'audio cover song identification',
#    'https://w3id.org/musow/vocab/audio-downbeat-estimation': 'audio downbeat estimation',
#    'https://w3id.org/musow/vocab/audio-effects-annotation': 'audio effects annotation',
#    'https://w3id.org/musow/vocab/audio-fingerprinting': 'audio fingerprinting',
#    'https://w3id.org/musow/vocab/audio-key-detection': 'audio key detection',
#    'https://w3id.org/musow/vocab/audio-melody-extraction': 'audio melody extraction',
#    'https://w3id.org/musow/vocab/audio-music-similarity-and-retrieval': 'audio music similarity and retrieval',
#    'https://w3id.org/musow/vocab/audio-offset-detection': 'audio offset detection',
#    'https://w3id.org/musow/vocab/audio-onset-detection': 'audio onset detection',
#    'https://w3id.org/musow/vocab/audio-pattern-matching': 'audio pattern matching',
#    'https://w3id.org/musow/vocab/audio-tag-classification': 'audio tag classification',
#    'https://w3id.org/musow/vocab/audio-tempo-estimation': 'audio tempo estimation',
#    'https://w3id.org/musow/vocab/automatic-lyrics-to-audio-alignment': 'automatic lyrics-to-audio alignment',
#    'https://w3id.org/musow/vocab/codicology': 'codicology',
#    'https://w3id.org/musow/vocab/comparative-studies': 'comparative studies',
#    'https://w3id.org/musow/vocab/cultural-studies': 'cultural studies',
#    'https://w3id.org/musow/vocab/data-aggregation': 'data aggregation',
#    'https://w3id.org/musow/vocab/data-conversion': 'data conversion',
#    'https://w3id.org/musow/vocab/data-visualization': 'data visualization',
#    'https://w3id.org/musow/vocab/discography': 'discography',
#    'https://w3id.org/musow/vocab/discovery-of-repeated-themes-&-sections': 'discovery of repeated themes & sections',
#    'https://w3id.org/musow/vocab/drum-transcription': 'drum transcription',
#    'https://w3id.org/musow/vocab/ethnography': 'ethnography',
#    'https://w3id.org/musow/vocab/genre-recognition': 'genre recognition',
#    'https://w3id.org/musow/vocab/gp3/gp4-collection': 'gp3/gp4 collection',
#    'https://w3id.org/musow/vocab/gp3/gp4-editor': 'gp3/gp4 editor',
#    'https://w3id.org/musow/vocab/history': 'history',
#    'https://w3id.org/musow/vocab/history-of-instruments': 'history of instruments',
#    'https://w3id.org/musow/vocab/history-of-theatre': 'history of theatre',
#    'https://w3id.org/musow/vocab/iconography': 'iconography',
#    'https://w3id.org/musow/vocab/image-annotation': 'image annotation',
#    'https://w3id.org/musow/vocab/literary-studies': 'literary studies',
#    'https://w3id.org/musow/vocab/lod-publication': 'lod publication',
#    'https://w3id.org/musow/vocab/machine-learning': 'machine learning',
#    'https://w3id.org/musow/vocab/measure-annotation': 'measure annotation',
#    'https://w3id.org/musow/vocab/metadata-aggregation': 'metadata aggregation',
#    'https://w3id.org/musow/vocab/midi-collection': 'midi collection',
#    'https://w3id.org/musow/vocab/multiple-fundamental-frequency-estimation-&-tracking': 'multiple fundamental frequency estimation & tracking',
#    'https://w3id.org/musow/vocab/music-analysis': 'music analysis',
#    'https://w3id.org/musow/vocab/music-annotation': 'music annotation',
#    'https://w3id.org/musow/vocab/music-history': 'music history',
#    'https://w3id.org/musow/vocab/music-information-retrieval': 'music information retrieval',
#    'https://w3id.org/musow/vocab/music-learning': 'music learning',
#    'https://w3id.org/musow/vocab/music-listening': 'music listening',
#    'https://w3id.org/musow/vocab/music-philology': 'music philology',
#    'https://w3id.org/musow/vocab/music-publishing-history': 'music publishing history',
#    'https://w3id.org/musow/vocab/music-recommendation': 'music recommendation',
#    'https://w3id.org/musow/vocab/music-selling': 'music selling',
#    'https://w3id.org/musow/vocab/music-style': 'music style',
#    'https://w3id.org/musow/vocab/musical-pattern-matching': 'musical pattern matching',
#    'https://w3id.org/musow/vocab/musicology': 'musicology',
#    'https://w3id.org/musow/vocab/network-analysis': 'network analysis',
#    'https://w3id.org/musow/vocab/omr': 'omr',
#    'https://w3id.org/musow/vocab/organology': 'organology',
#    'https://w3id.org/musow/vocab/paleography': 'paleography',
#    'https://w3id.org/musow/vocab/performance': 'performance',
#    'https://w3id.org/musow/vocab/performanceperformance': 'performanceperformance',
#    'https://w3id.org/musow/vocab/popular-music': 'popular music',
#    'https://w3id.org/musow/vocab/psychological-testing': 'psychological testing',
#    'https://w3id.org/musow/vocab/query-by-singing/humming': 'query by singing/humming',
#    'https://w3id.org/musow/vocab/query-by-tapping': 'query by tapping',
#    'https://w3id.org/musow/vocab/real-time-audio-to-score-alignment-(a.k.a-score-following)': 'real-time audio to score alignment (a.k.a score following)',
#    'https://w3id.org/musow/vocab/recommendation': 'recommendation',
#    'https://w3id.org/musow/vocab/religious-history': 'religious history',
#    'https://w3id.org/musow/vocab/score-audio-linkage': 'score-audio linkage',
#    'https://w3id.org/musow/vocab/set-list-identification': 'set list identification',
#    'https://w3id.org/musow/vocab/singing-voice-separation': 'singing voice separation',
#    'https://w3id.org/musow/vocab/social-history': 'social history',
#    'https://w3id.org/musow/vocab/social-studies': 'social studies',
#    'https://w3id.org/musow/vocab/structural-segmentation': 'structural segmentation',
#    'https://w3id.org/musow/vocab/symbolic-melodic-similarity': 'symbolic melodic similarity',
#    'https://w3id.org/musow/vocab/theology': 'theology'}},
#  {'browse': 'False',
#   'cache_autocomplete': 'off',
#   'class': 'col-md-11',
#   'disabled': 'False',
#   'disambiguate': 'False',
#   'id': 'res_features',
#   'label': 'technical features',
#   'placeholder': '',
#   'prepend': 'The technical features that the online resource offers',
#   'property': 'https://schema.org/featureList',
#   'searchWikidata': 'False',
#   'type': 'Checkbox',
#   'value': 'URI',
#   'values': {'https://w3id.org/musow/vocab/api': 'Offers a Web API',
#    'https://w3id.org/musow/vocab/browse-interface': 'Provides interfaces for browsing contents',
#    'https://w3id.org/musow/vocab/data-dump': 'Offers data export or dump',
#    'https://w3id.org/musow/vocab/human-consumption': 'Provides user-friendly interfaces',
#    'https://w3id.org/musow/vocab/interoperable': 'Shares data in open data formats',
#    'https://w3id.org/musow/vocab/machine-readable': 'Serves machine-readable music data',
#    'https://w3id.org/musow/vocab/playable': 'Offers playable music records',
#    'https://w3id.org/musow/vocab/search-interface': 'Provides user-friendly search interfaces',
#    'https://w3id.org/musow/vocab/sparql-endpoint': 'Has a SPARQL endpoint'}},
#  {'browse': 'False',
#   'cache_autocomplete': 'off',
#   'class': 'col-md-11',
#   'disabled': 'False',
#   'disambiguate': 'False',
#   'id': 'res_reused',
#   'label': 'reused resources',
#   'placeholder': 'Gutenberg project',
#   'prepend': 'A tool, a dataset, a vocabulary, or any other component that is reused by the resource',
#   'property': 'https://schema.org/isBasedOn',
#   'searchWikidata': 'True',
#   'type': 'Textbox',
#   'value': 'URI'},
#  {'browse': 'False',
#   'cache_autocomplete': 'off',
#   'class': 'col-md-11',
#   'disabled': 'False',
#   'disambiguate': 'False',
#   'id': 'res_example',
#   'label': 'example resource',
#   'placeholder': 'e.g. https://led.kmi.open.ac.uk/entity/lexp/1628588049214',
#   'prepend': 'If the resource collects music-related resources, the URL of an exemplar resource',
#   'property': 'https://schema.org/workExample',
#   'searchWikidata': 'False',
#   'type': 'Textbox',
#   'value': 'Literal'},
#  {'browse': 'True',
#   'cache_autocomplete': 'off',
#   'class': 'col-md-11',
#   'disabled': 'False',
#   'disambiguate': 'False',
#   'id': 'res_subject',
#   'label': 'type of collected resources',
#   'placeholder': '',
#   'prepend': 'If the resource collects music-related resources, what are these?',
#   'property': 'https://schema.org/mainEntity',
#   'searchWikidata': 'False',
#   'type': 'Checkbox',
#   'value': 'URI',
#   'values': {'http://purl.org/ontology/mo/AnalogSignal': 'Analog Signal',
#    'http://purl.org/ontology/mo/Instrument': 'Instrument',
#    'http://purl.org/ontology/mo/Libretto': 'Libretto',
#    'http://purl.org/ontology/mo/MusicArtist': 'Music Artist',
#    'http://purl.org/ontology/mo/MusicalManifestation': 'Musical Manifestation',
#    'http://purl.org/ontology/mo/MusicalWork': 'Musical Work',
#    'http://purl.org/ontology/mo/Performance': 'Performance',
#    'http://purl.org/ontology/mo/Record': 'Record',
#    'http://purl.org/ontology/mo/Recording': 'Recording',
#    'http://purl.org/ontology/mo/Score': 'Score',
#    'http://purl.org/ontology/mo/Signal': 'Signal',
#    'http://purl.org/ontology/mo/Track': 'Track',
#    'https://w3id.org/musow/vocab/audio': 'Audio',
#    'https://w3id.org/musow/vocab/listening-experience': 'Listening experience',
#    'https://w3id.org/musow/vocab/musical-resource': 'Musical resource',
#    'https://w3id.org/musow/vocab/publisher': 'Publisher',
#    'https://w3id.org/musow/vocab/tabs': 'Tabs'}},
#  {'browse': 'False',
#   'cache_autocomplete': 'off',
#   'class': 'col-md-11',
#   'disabled': 'False',
#   'disambiguate': 'False',
#   'id': 'res_scope',
#   'label': 'scope of the collection',
#   'placeholder': '',
#   'prepend': 'If the resource collects music-related resources, what is the scope of the collection?',
#   'property': 'https://schema.org/about',
#   'searchWikidata': 'False',
#   'type': 'Checkbox',
#   'value': 'URI',
#   'values': {'https://w3id.org/musow/vocab/artist': 'Artist',
#    'https://w3id.org/musow/vocab/genre': 'Genre',
#    'https://w3id.org/musow/vocab/geographical': 'Geographical',
#    'https://w3id.org/musow/vocab/temporal': 'Temporal'}},
#  {'browse': 'False',
#   'cache_autocomplete': 'off',
#   'class': 'col-md-11',
#   'disabled': 'False',
#   'disambiguate': 'False',
#   'id': 'res_temporal',
#   'label': 'temporal scope of data',
#   'placeholder': 'e.g. XX century',
#   'prepend': 'Which historical period does the resource address?',
#   'property': 'https://schema.org/temporalCoverage',
#   'searchWikidata': 'True',
#   'type': 'Textbox',
#   'value': 'URI'},
#  {'browse': 'False',
#   'cache_autocomplete': 'off',
#   'class': 'col-md-11',
#   'disabled': 'False',
#   'disambiguate': 'False',
#   'id': 'res_geo',
#   'label': 'geographical scope of data',
#   'placeholder': 'e.g. Italy',
#   'prepend': 'Which geographical places does the resource address?',
#   'property': 'https://schema.org/spatialCoverage',
#   'searchWikidata': 'True',
#   'type': 'Textbox',
#   'value': 'URI'},
#  {'browse': 'False',
#   'cache_autocomplete': 'off',
#   'class': 'col-md-11',
#   'disabled': 'False',
#   'disambiguate': 'False',
#   'id': 'res_genre',
#   'label': 'music genre in scope',
#   'placeholder': 'e.g. Jazz',
#   'prepend': 'Which music genres does the resource address?',
#   'property': 'https://schema.org/genre',
#   'searchWikidata': 'True',
#   'type': 'Textbox',
#   'value': 'URI'},
#  {'browse': 'False',
#   'cache_autocomplete': 'off',
#   'class': 'col-md-11',
#   'disabled': 'False',
#   'disambiguate': 'False',
#   'id': 'res_artist',
#   'label': 'people in scope',
#   'placeholder': 'e.g. Louis Armstrong',
#   'prepend': 'Which composers, performers, or interesting people does the resource address?',
#   'property': 'https://schema.org/character',
#   'searchWikidata': 'True',
#   'type': 'Textbox',
#   'value': 'URI'},
#  {'browse': 'True',
#   'cache_autocomplete': 'off',
#   'class': 'col-md-11',
#   'disabled': 'False',
#   'disambiguate': 'False',
#   'id': 'res_category',
#   'label': 'category of data collected',
#   'placeholder': '',
#   'prepend': 'If the resource collects music-related resources, what kind of data are provided for the resources?',
#   'property': 'https://schema.org/category',
#   'searchWikidata': 'False',
#   'type': 'Checkbox',
#   'value': 'URI',
#   'values': {'https://w3id.org/musow/vocab/media': 'Media',
#    'https://w3id.org/musow/vocab/metadata': 'Metadata',
#    'https://w3id.org/musow/vocab/symbolic': 'Symbolic'}},
#  {'browse': 'True',
#   'cache_autocomplete': 'off',
#   'class': 'col-md-11',
#   'disabled': 'False',
#   'disambiguate': 'False',
#   'id': 'res_music_feature',
#   'label': 'music data features',
#   'placeholder': '',
#   'prepend': 'If the resource collects symbolic data of music resources, what type of music feature is provided as structured data?',
#   'property': 'https://schema.org/keywords',
#   'searchWikidata': 'False',
#   'type': 'Checkbox',
#   'value': 'URI',
#   'values': {'https://w3id.org/musow/vocab/contour-shape': 'Contour/Shape',
#    'https://w3id.org/musow/vocab/descriptive-metadata': 'Descriptive metadata',
#    'https://w3id.org/musow/vocab/harmony': 'Harmony',
#    'https://w3id.org/musow/vocab/lyrics': 'Lyrics',
#    'https://w3id.org/musow/vocab/melody': 'Melody',
#    'https://w3id.org/musow/vocab/rhythm': 'Rhythm',
#    'https://w3id.org/musow/vocab/structure': 'Music structure',
#    'https://w3id.org/musow/vocab/timbre': 'Timbre'}},
#  {'browse': 'True',
#   'cache_autocomplete': 'off',
#   'class': 'col-md-11',
#   'disabled': 'False',
#   'disambiguate': 'False',
#   'id': 'res_collectionsize',
#   'label': 'collection size',
#   'placeholder': '',
#   'prepend': 'If the resource collects music-related resources, can you estimate the size of the collection?',
#   'property': 'https://schema.org/collectionSize',
#   'searchWikidata': 'False',
#   'type': 'Dropdown',
#   'value': 'URI',
#   'values': {'https://w3id.org/musow/vocab/gt-1m': '>1M',
#    'https://w3id.org/musow/vocab/lt-10': '<10',
#    'https://w3id.org/musow/vocab/lt-100': '<100',
#    'https://w3id.org/musow/vocab/lt-1000': '<1000',
#    'https://w3id.org/musow/vocab/lt-10000': '<10000',
#    'https://w3id.org/musow/vocab/lt-100000': '<100000',
#    'https://w3id.org/musow/vocab/lt-1m': '<1M'}},
#  {'browse': 'False',
#   'cache_autocomplete': 'off',
#   'class': 'col-md-11',
#   'disabled': 'False',
#   'disambiguate': 'False',
#   'id': 'res_format',
#   'label': 'data formats',
#   'placeholder': '',
#   'prepend': 'If the resource collects music-related resources, in what data format are these served?',
#   'property': 'https://schema.org/encodingFormat',
#   'searchWikidata': 'False',
#   'type': 'Checkbox',
#   'value': 'URI',
#   'values': {'https://w3id.org/musow/vocab/audio': 'audio',
#    'https://w3id.org/musow/vocab/cap/xml': 'cap/xml',
#    'https://w3id.org/musow/vocab/csv': 'csv',
#    'https://w3id.org/musow/vocab/djvu': 'djvu',
#    'https://w3id.org/musow/vocab/ead': 'ead',
#    'https://w3id.org/musow/vocab/finale': 'finale',
#    'https://w3id.org/musow/vocab/flac': 'flac',
#    'https://w3id.org/musow/vocab/gif': 'gif',
#    'https://w3id.org/musow/vocab/gp3/gp4': 'gp3/gp4',
#    'https://w3id.org/musow/vocab/html': 'html',
#    'https://w3id.org/musow/vocab/html5': 'html5',
#    'https://w3id.org/musow/vocab/humdrum': 'humdrum',
#    'https://w3id.org/musow/vocab/iiif': 'iiif',
#    'https://w3id.org/musow/vocab/jpg': 'jpg',
#    'https://w3id.org/musow/vocab/js': 'js',
#    'https://w3id.org/musow/vocab/json': 'json',
#    'https://w3id.org/musow/vocab/json-ld': 'json-ld',
#    'https://w3id.org/musow/vocab/kern': 'kern',
#    'https://w3id.org/musow/vocab/lab': 'lab',
#    'https://w3id.org/musow/vocab/latex': 'latex',
#    'https://w3id.org/musow/vocab/lilypond': 'lilypond',
#    'https://w3id.org/musow/vocab/mag/xml': 'mag/xml',
#    'https://w3id.org/musow/vocab/marc': 'marc',
#    'https://w3id.org/musow/vocab/marcxml': 'marcxml',
#    'https://w3id.org/musow/vocab/mei/xml': 'mei/xml',
#    'https://w3id.org/musow/vocab/mets/xml': 'mets/xml',
#    'https://w3id.org/musow/vocab/midi': 'midi',
#    'https://w3id.org/musow/vocab/mods/xml': 'mods/xml',
#    'https://w3id.org/musow/vocab/mov': 'mov',
#    'https://w3id.org/musow/vocab/mp3': 'mp3',
#    'https://w3id.org/musow/vocab/mpeg-a': 'mpeg-a',
#    'https://w3id.org/musow/vocab/mu2': 'mu2',
#    'https://w3id.org/musow/vocab/musedata': 'musedata',
#    'https://w3id.org/musow/vocab/musescore': 'musescore',
#    'https://w3id.org/musow/vocab/musicxml': 'musicxml',
#    'https://w3id.org/musow/vocab/mxl': 'mxl',
#    'https://w3id.org/musow/vocab/myr': 'myr',
#    'https://w3id.org/musow/vocab/notearray': 'notearray',
#    'https://w3id.org/musow/vocab/noteworthy': 'noteworthy',
#    'https://w3id.org/musow/vocab/ogg': 'ogg',
#    'https://w3id.org/musow/vocab/owl': 'owl',
#    'https://w3id.org/musow/vocab/pdf': 'pdf',
#    'https://w3id.org/musow/vocab/png': 'png',
#    'https://w3id.org/musow/vocab/prov': 'prov',
#    'https://w3id.org/musow/vocab/py': 'py',
#    'https://w3id.org/musow/vocab/python': 'python',
#    'https://w3id.org/musow/vocab/ram': 'ram',
#    'https://w3id.org/musow/vocab/rdf': 'rdf',
#    'https://w3id.org/musow/vocab/realaudio': 'realaudio',
#    'https://w3id.org/musow/vocab/rng': 'rng',
#    'https://w3id.org/musow/vocab/sibelius': 'sibelius',
#    'https://w3id.org/musow/vocab/skos': 'skos',
#    'https://w3id.org/musow/vocab/svg': 'svg',
#    'https://w3id.org/musow/vocab/tei': 'tei',
#    'https://w3id.org/musow/vocab/tei/xml': 'tei/xml',
#    'https://w3id.org/musow/vocab/tiff': 'tiff',
#    'https://w3id.org/musow/vocab/txt': 'txt',
#    'https://w3id.org/musow/vocab/video': 'video',
#    'https://w3id.org/musow/vocab/wav': 'wav',
#    'https://w3id.org/musow/vocab/xls': 'xls',
#    'https://w3id.org/musow/vocab/xml': 'xml',
#    'https://w3id.org/musow/vocab/xsl': 'xsl',
#    'https://w3id.org/musow/vocab/xslx': 'xslx'}},
#  {'browse': 'True',
#   'cache_autocomplete': 'off',
#   'class': 'col-md-11',
#   'disabled': 'False',
#   'disambiguate': 'False',
#   'id': 'res_license',
#   'label': 'data license',
#   'placeholder': '',
#   'prepend': 'If the resource collects music-related resources, which licence is specified for their reuse?',
#   'property': 'https://schema.org/license',
#   'searchWikidata': 'False',
#   'type': 'Dropdown',
#   'value': 'URI',
#   'values': {'https://w3id.org/musow/vocab/cc-by': 'CC-BY',
#    'https://w3id.org/musow/vocab/cc-by-3.0': 'CC BY 3.0',
#    'https://w3id.org/musow/vocab/cc-by-4.0': 'CC-BY 4.0',
#    'https://w3id.org/musow/vocab/cc-by-nc': 'CC-BY-NC',
#    'https://w3id.org/musow/vocab/cc-by-nc-nd': 'CC-BY-NC-ND',
#    'https://w3id.org/musow/vocab/cc-by-nc-sa': 'CC-BY-NC-SA',
#    'https://w3id.org/musow/vocab/cc-by-sa': 'CC-BY-SA',
#    'https://w3id.org/musow/vocab/cc0': 'CC0',
#    'https://w3id.org/musow/vocab/copyright': 'Copyright',
#    'https://w3id.org/musow/vocab/gnu-fdl': 'GNU-FDL',
#    'https://w3id.org/musow/vocab/gnu-gpl': 'GNU-GPL',
#    'https://w3id.org/musow/vocab/mit-license': 'MIT License',
#    'https://w3id.org/musow/vocab/not-specified': 'Not specified',
#    'https://w3id.org/musow/vocab/open-access': 'Open Access',
#    'https://w3id.org/musow/vocab/privative': 'Privative'}},
#  {'browse': 'True',
#   'cache_autocomplete': 'off',
#   'class': 'col-md-11',
#   'disabled': 'False',
#   'disambiguate': 'False',
#   'id': 'res_datasize',
#   'label': 'data size',
#   'placeholder': '',
#   'prepend': 'If the resource serves data, can you estimate of the size of data?',
#   'property': 'https://schema.org/contentSize',
#   'searchWikidata': 'False',
#   'type': 'Dropdown',
#   'value': 'URI',
#   'values': {'https://w3id.org/musow/vocab/gb': '~Gb',
#    'https://w3id.org/musow/vocab/kb': '~Kb',
#    'https://w3id.org/musow/vocab/mb': '~Mb'}},
#  {'browse': 'False',
#   'cache_autocomplete': 'off',
#   'class': 'col-md-11',
#   'disabled': 'False',
#   'disambiguate': 'False',
#   'id': 'res_distribution',
#   'label': 'data download URL',
#   'placeholder': 'e.g. https://led.kmi.open.ac.uk/rdf/export/led-SNAPSHOT.nt.bz2',
#   'prepend': 'If the resource serves data, the URL of the latest data distribution',
#   'property': 'https://schema.org/downloadUrl',
#   'searchWikidata': 'False',
#   'type': 'Textbox',
#   'value': 'Literal'},
#  {'browse': 'False',
#   'cache_autocomplete': 'off',
#   'class': 'col-md-11',
#   'disabled': 'False',
#   'disambiguate': 'False',
#   'id': 'res_sparql',
#   'label': 'SPARQL endpoint',
#   'placeholder': 'e.g. https://data.open.ac.uk/query',
#   'prepend': 'If the resource serves data, the URL of the SPARQL endpoint of the resource, if applicable',
#   'property': 'http://rdfs.org/ns/void#sparqlEndpoint',
#   'searchWikidata': 'False',
#   'type': 'Textbox',
#   'value': 'Literal'},
#  {'browse': 'False',
#   'cache_autocomplete': 'off',
#   'class': 'col-md-11',
#   'disabled': 'False',
#   'disambiguate': 'False',
#   'id': 'res_api',
#   'label': 'web API',
#   'placeholder': 'e.g. http://example.org/api/',
#   'prepend': 'If the resource serves data, the URL of the API',
#   'property': 'https://schema.org/serviceUrl',
#   'searchWikidata': 'False',
#   'type': 'Textbox',
#   'value': 'Literal'}]
